# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: Gil Garcera, Javier
# *   Alumno 2: Palomares Mateo, Abel
# *   Alumno 3: Serrano López, Francisco Rubén
# *   Alumno 4: Vegas Romero, David

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/actividades/proyecto practico"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# Archivos en el directorio:
# ['dqn_SpaceInvaders-v0_weights_1000000.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights_1500000.h5f.index', 'alternativa_google_collab.txt', 'dqn_SpaceInvaders-v0_weights.h5f.data-00000-of-00001', 'README.md', 'dqn_SpaceInvaders-v0_weights_250000.h5f.index', '.gitignore', 'dqn_SpaceInvaders-v0_weights_750000.h5f.index', 'Proyecto_práctico.ipynb', 'dqn_SpaceInvaders-v0_weights.h5f.index', 'dqn_SpaceInvaders-v0_log.json', 'dqn_SpaceInvaders-v0_weights_1750000.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights_500000.h5f.index', 'Proyecto_práctico_local.ipynb', 'dqn_SpaceInvaders-v0_weights_750000.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights_250000.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights_1500000.h5f.data-00000-of-00001', 'dqn_SpaceInvaders-v0_weights_1000000.h5f.index', 'dqn_SpaceInvaders-v0_weights_1750000.h5f.index', '.ipynb_checkpoints', 'dqn_SpaceInvaders-v0_weights_1250000.h5f.index', 'dqn_SpaceInvaders-v0_weights_500000.h5f.data-00000-of-00001', 'checkpoint', 'dqn_SpaceInvaders-v0_weights_1250000.h5f.data-00000-of-00001']

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.8
  # %pip install tensorflow==2.12.1
else:
  # %pip install numpy==1.23.5
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.10.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.12.0
  # %pip install tensorflow==2.12.1
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute
#from tensorflow.keras.optimizers import Adam
from tensorflow.keras.optimizers.legacy import Adam

import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint
import tensorflow as tf

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
print("Numero de acciones disponibles:" + str(nb_actions))
print("Formato de las observaciones:")
#env.observation_space
## Next, we build a very simple model.
#model = Sequential()
#model.add(Flatten(input_shape=(1,) + env.observation_space.shape))
#model.add(Dense(16))
#model.add(Activation('relu'))
#model.add(Dense(16))
#model.add(Activation('relu'))
#model.add(Dense(16))
#model.add(Activation('relu'))
#model.add(Dense(nb_actions))
#model.add(Activation('linear'))
#print(model.summary())


# Next, we build our model. We use the same model that was described by Mnih et al. (2015).
input_shape = (WINDOW_LENGTH,) + INPUT_SHAPE
model = Sequential()
print(K.image_data_format())
if K.image_data_format() == 'channels_last':
    # (width, height, channels)
    model.add(Permute((2, 3, 1), input_shape=input_shape))
elif K.image_data_format() == 'channels_first':
    # (channels, width, height)
    model.add(Permute((1, 2, 3), input_shape=input_shape))
else:
    raise RuntimeError('Unknown image_dim_ordering.')

model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
model.add(Activation('relu'))
model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
model.add(Activation('relu'))
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dense(nb_actions))
model.add(Activation('linear'))
print(model.summary())
# Out:
# Numero de acciones disponibles:6
# Formato de las observaciones:
# channels_last
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  permute_1 (Permute)         (None, 84, 84, 4)         0
#
#  conv2d_3 (Conv2D)           (None, 20, 20, 32)        8224
#
#  activation_5 (Activation)   (None, 20, 20, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 9, 9, 64)          32832
#
#  activation_6 (Activation)   (None, 9, 9, 64)          0
#
#  conv2d_5 (Conv2D)           (None, 7, 7, 64)          36928
#
#  activation_7 (Activation)   (None, 7, 7, 64)          0
#
#  flatten_1 (Flatten)         (None, 3136)              0
#
#  dense_2 (Dense)             (None, 512)               1606144
#
#  activation_8 (Activation)   (None, 512)               0
#
#  dense_3 (Dense)             (None, 6)                 3078
#
#  activation_9 (Activation)   (None, 6)                 0
#
# =================================================================
# Total params: 1,687,206
# Trainable params: 1,687,206
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
"""# Let's define the memory for storing the experience
memory = SequentialMemory(limit=50000, window_length=1)

# Define the policy that our agent will follow
policy = BoltzmannQPolicy()

# Define the agent
dqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory,
               nb_steps_warmup=10,
               target_model_update=1e-2, policy=policy)

adam_obj = Adam(learning_rate=1e-3)
dqn.compile(adam_obj, metrics=['mae'])

# Train the agent
dqn.fit(env, nb_steps=50000, visualize=False, verbose=2)

# After training is done, we save the final weights.
dqn.save_weights('dqn_{}_weights.h5f'.format(ENV_NAME), overwrite=True)
# Finally, evaluate our algorithm for 5 episodes.
dqn.load_weights('dqn_{}_weights.h5f'.format(ENV_NAME))
dqn.test(env, nb_episodes=10, visualize=False)
"""
# Out:
# "# Let's define the memory for storing the experience\nmemory = SequentialMemory(limit=50000, window_length=1)\n\n# Define the policy that our agent will follow\npolicy = BoltzmannQPolicy()\n\n# Define the agent\ndqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory,\n               nb_steps_warmup=10,\n               target_model_update=1e-2, policy=policy)\n\nadam_obj = Adam(learning_rate=1e-3)\ndqn.compile(adam_obj, metrics=['mae'])\n\n# Train the agent\ndqn.fit(env, nb_steps=50000, visualize=False, verbose=2)\n\n# After training is done, we save the final weights.\ndqn.save_weights('dqn_{}_weights.h5f'.format(ENV_NAME), overwrite=True)\n# Finally, evaluate our algorithm for 5 episodes.\ndqn.load_weights('dqn_{}_weights.h5f'.format(ENV_NAME))\ndqn.test(env, nb_episodes=10, visualize=False)\n"

# %%
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)
processor = AtariProcessor()

#policy = LinearAnnealedPolicy(EpsGreedyQPolicy(), attr='eps',
#                              value_max=1., value_min=.1, value_test=.05,
#                              nb_steps=1000000)
#dqn = DQNAgent(model=model, nb_actions=nb_actions, policy=policy,
#               memory=memory, processor=processor,
#               nb_steps_warmup=50000, gamma=.99,
#               target_model_update=10000,
#               train_interval=4)
#dqn.compile(Adam(learning_rate=.00025), metrics=['mae'])

policy = BoltzmannQPolicy()

# Define the agent
dqn = DQNAgent(model=model, nb_actions=nb_actions, memory=memory,
               nb_steps_warmup=50000, gamma=.99,
               train_interval=4, processor=processor,
               target_model_update=1e-2, policy=policy)

adam_obj = Adam(learning_rate=1e-3)
dqn.compile(adam_obj, metrics=['mae'])

# Training part
weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
checkpoint_weights_filename = 'dqn_' + env_name + '_weights_{step}.h5f'
log_filename = 'dqn_{}_log.json'.format(env_name)
callbacks = [ModelIntervalCheckpoint(checkpoint_weights_filename, interval=250000)]
callbacks += [FileLogger(log_filename, interval=100)]
# Out:
# 2025-06-29 14:20:39.187762: W tensorflow/c/c_api.cc:300] Operation '{name:'dense_2_2/kernel/Assign' id:1057 op device:{requested: '', assigned: ''} def:{{{node dense_2_2/kernel/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](dense_2_2/kernel, dense_2_2/kernel/Initializer/stateless_random_uniform)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.

# %% [markdown]
# 2. Implementación de la solución DQN

# %%
dqn.fit(env, callbacks=callbacks, nb_steps=1750000, log_interval=10000, visualize=False)

dqn.save_weights(weights_filename, overwrite=True)
# Out:
# Training for 1750000 steps ...
# Interval 1 (0 steps performed)
#     9/10000 [..............................] - ETA: 1:05 - reward: 0.0000e+00
# 2025-06-29 14:20:44.217297: W tensorflow/c/c_api.cc:300] Operation '{name:'activation_9/activation_9/Identity' id:967 op device:{requested: '', assigned: ''} def:{{{node activation_9/activation_9/Identity}} = Identity[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_3_1/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-06-29 14:20:44.263122: W tensorflow/c/c_api.cc:300] Operation '{name:'total_4/Assign' id:1269 op device:{requested: '', assigned: ''} def:{{{node total_4/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](total_4, total_4/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 10000/10000 [==============================] - 58s 6ms/step - reward: 0.0135
# 14 episodes - episode_reward: 9.500 [3.000, 19.000] - ale.lives: 2.144
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 55s 5ms/step - reward: 0.0137
# 14 episodes - episode_reward: 9.500 [4.000, 20.000] - ale.lives: 2.111
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 55s 5ms/step - reward: 0.0141
# 13 episodes - episode_reward: 10.692 [5.000, 20.000] - ale.lives: 2.157
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 55s 5ms/step - reward: 0.0128
# 13 episodes - episode_reward: 10.154 [2.000, 22.000] - ale.lives: 2.183
#
# Interval 5 (40000 steps performed)
# 10000/10000 [==============================] - 55s 5ms/step - reward: 0.0133
# 14 episodes - episode_reward: 9.643 [3.000, 23.000] - ale.lives: 2.168
#
# Interval 6 (50000 steps performed)
#     1/10000 [..............................] - ETA: 1:49 - reward: 0.0000e+00
# 2025-06-29 14:25:22.404337: W tensorflow/c/c_api.cc:300] Operation '{name:'activation_9_1/activation_9/Identity' id:1092 op device:{requested: '', assigned: ''} def:{{{node activation_9_1/activation_9/Identity}} = Identity[T=DT_FLOAT, _has_manual_control_dependencies=true](dense_3_2/BiasAdd)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-06-29 14:25:22.662928: W tensorflow/c/c_api.cc:300] Operation '{name:'loss_9/AddN' id:1400 op device:{requested: '', assigned: ''} def:{{{node loss_9/AddN}} = AddN[N=2, T=DT_FLOAT, _has_manual_control_dependencies=true](loss_9/mul, loss_9/mul_1)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 2025-06-29 14:25:22.713205: W tensorflow/c/c_api.cc:300] Operation '{name:'training/Adam/dense_2_1/bias/m/Assign' id:1618 op device:{requested: '', assigned: ''} def:{{{node training/Adam/dense_2_1/bias/m/Assign}} = AssignVariableOp[_has_manual_control_dependencies=true, dtype=DT_FLOAT, validate_shape=false](training/Adam/dense_2_1/bias/m, training/Adam/dense_2_1/bias/m/Initializer/zeros)}}' was changed by setting attribute after it was run by a session. This mutation will have no effect, and will trigger an error in the future. Either don't modify nodes after running them or create a new session.
# 10000/10000 [==============================] - 384s 38ms/step - reward: 0.0132
# 14 episodes - episode_reward: 8.857 [3.000, 15.000] - loss: 0.007 - mae: 0.174 - mean_q: 0.219 - ale.lives: 2.071
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 386s 39ms/step - reward: 0.0135
# 14 episodes - episode_reward: 9.643 [4.000, 17.000] - loss: 0.007 - mae: 0.448 - mean_q: 0.551 - ale.lives: 2.065
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 386s 39ms/step - reward: 0.0132
# 14 episodes - episode_reward: 10.071 [5.000, 18.000] - loss: 0.007 - mae: 0.665 - mean_q: 0.812 - ale.lives: 1.872
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 388s 39ms/step - reward: 0.0148
# 14 episodes - episode_reward: 10.571 [6.000, 15.000] - loss: 0.007 - mae: 0.816 - mean_q: 0.993 - ale.lives: 2.277
#
# Interval 10 (90000 steps performed)
# 10000/10000 [==============================] - 394s 39ms/step - reward: 0.0136
# 15 episodes - episode_reward: 8.000 [4.000, 15.000] - loss: 0.008 - mae: 0.963 - mean_q: 1.170 - ale.lives: 2.109
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 392s 39ms/step - reward: 0.0126
# 15 episodes - episode_reward: 8.000 [3.000, 18.000] - loss: 0.008 - mae: 1.073 - mean_q: 1.302 - ale.lives: 2.099
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 392s 39ms/step - reward: 0.0139
# 15 episodes - episode_reward: 10.333 [4.000, 26.000] - loss: 0.008 - mae: 1.147 - mean_q: 1.391 - ale.lives: 2.050
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 394s 39ms/step - reward: 0.0150
# 12 episodes - episode_reward: 12.833 [3.000, 21.000] - loss: 0.008 - mae: 1.193 - mean_q: 1.447 - ale.lives: 2.054
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 395s 39ms/step - reward: 0.0125
# 14 episodes - episode_reward: 8.714 [3.000, 16.000] - loss: 0.008 - mae: 1.230 - mean_q: 1.492 - ale.lives: 2.144
#
# Interval 15 (140000 steps performed)
# 10000/10000 [==============================] - 396s 40ms/step - reward: 0.0139
# 17 episodes - episode_reward: 8.235 [3.000, 17.000] - loss: 0.008 - mae: 1.268 - mean_q: 1.536 - ale.lives: 2.070
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 398s 40ms/step - reward: 0.0138
# 14 episodes - episode_reward: 9.786 [5.000, 18.000] - loss: 0.009 - mae: 1.299 - mean_q: 1.573 - ale.lives: 2.223
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 399s 40ms/step - reward: 0.0129
# 15 episodes - episode_reward: 8.533 [4.000, 14.000] - loss: 0.009 - mae: 1.331 - mean_q: 1.612 - ale.lives: 2.092
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 402s 40ms/step - reward: 0.0139
# 16 episodes - episode_reward: 9.062 [3.000, 14.000] - loss: 0.009 - mae: 1.359 - mean_q: 1.644 - ale.lives: 2.183
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 403s 40ms/step - reward: 0.0134
# 14 episodes - episode_reward: 9.000 [5.000, 18.000] - loss: 0.009 - mae: 1.371 - mean_q: 1.660 - ale.lives: 2.093
#
# Interval 20 (190000 steps performed)
# 10000/10000 [==============================] - 404s 40ms/step - reward: 0.0132
# 16 episodes - episode_reward: 8.750 [5.000, 15.000] - loss: 0.009 - mae: 1.383 - mean_q: 1.673 - ale.lives: 2.094
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 410s 41ms/step - reward: 0.0121
# 14 episodes - episode_reward: 8.500 [2.000, 20.000] - loss: 0.009 - mae: 1.380 - mean_q: 1.670 - ale.lives: 2.010
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 410s 41ms/step - reward: 0.0122
# 16 episodes - episode_reward: 7.812 [3.000, 13.000] - loss: 0.009 - mae: 1.361 - mean_q: 1.646 - ale.lives: 2.066
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 408s 41ms/step - reward: 0.0140
# 15 episodes - episode_reward: 9.000 [4.000, 16.000] - loss: 0.009 - mae: 1.363 - mean_q: 1.648 - ale.lives: 2.149
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 408s 41ms/step - reward: 0.0139
# 14 episodes - episode_reward: 9.714 [4.000, 22.000] - loss: 0.009 - mae: 1.358 - mean_q: 1.644 - ale.lives: 2.143
#
# Interval 25 (240000 steps performed)
# 10000/10000 [==============================] - 409s 41ms/step - reward: 0.0142
# 13 episodes - episode_reward: 10.615 [4.000, 15.000] - loss: 0.009 - mae: 1.354 - mean_q: 1.638 - ale.lives: 2.012
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 413s 41ms/step - reward: 0.0149
# 14 episodes - episode_reward: 10.357 [6.000, 25.000] - loss: 0.009 - mae: 1.346 - mean_q: 1.628 - ale.lives: 2.123
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 413s 41ms/step - reward: 0.0114
# 14 episodes - episode_reward: 9.071 [4.000, 21.000] - loss: 0.009 - mae: 1.344 - mean_q: 1.625 - ale.lives: 2.212
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 413s 41ms/step - reward: 0.0140
# 14 episodes - episode_reward: 10.214 [6.000, 18.000] - loss: 0.008 - mae: 1.342 - mean_q: 1.621 - ale.lives: 2.090
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 406s 41ms/step - reward: 0.0132
# 15 episodes - episode_reward: 8.000 [4.000, 19.000] - loss: 0.009 - mae: 1.335 - mean_q: 1.615 - ale.lives: 2.228
#
# Interval 30 (290000 steps performed)
# 10000/10000 [==============================] - 407s 41ms/step - reward: 0.0142
# 15 episodes - episode_reward: 10.000 [4.000, 23.000] - loss: 0.008 - mae: 1.325 - mean_q: 1.603 - ale.lives: 2.112
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 415s 42ms/step - reward: 0.0138
# 13 episodes - episode_reward: 10.231 [5.000, 20.000] - loss: 0.009 - mae: 1.338 - mean_q: 1.619 - ale.lives: 2.034
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 421s 42ms/step - reward: 0.0140
# 16 episodes - episode_reward: 8.812 [4.000, 21.000] - loss: 0.009 - mae: 1.339 - mean_q: 1.618 - ale.lives: 2.172
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 422s 42ms/step - reward: 0.0134
# 15 episodes - episode_reward: 9.133 [5.000, 16.000] - loss: 0.009 - mae: 1.330 - mean_q: 1.607 - ale.lives: 2.241
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 422s 42ms/step - reward: 0.0120
# 13 episodes - episode_reward: 9.462 [5.000, 18.000] - loss: 0.009 - mae: 1.325 - mean_q: 1.602 - ale.lives: 2.039
#
# Interval 35 (340000 steps performed)
# 10000/10000 [==============================] - 421s 42ms/step - reward: 0.0129
# 16 episodes - episode_reward: 7.562 [2.000, 16.000] - loss: 0.008 - mae: 1.336 - mean_q: 1.615 - ale.lives: 2.105
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 421s 42ms/step - reward: 0.0123
# 15 episodes - episode_reward: 8.067 [4.000, 17.000] - loss: 0.009 - mae: 1.343 - mean_q: 1.624 - ale.lives: 2.252
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 422s 42ms/step - reward: 0.0134
# 15 episodes - episode_reward: 8.600 [6.000, 16.000] - loss: 0.009 - mae: 1.354 - mean_q: 1.637 - ale.lives: 2.055
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 424s 42ms/step - reward: 0.0122
# 14 episodes - episode_reward: 9.500 [0.000, 18.000] - loss: 0.008 - mae: 1.341 - mean_q: 1.621 - ale.lives: 2.126
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 423s 42ms/step - reward: 0.0121
# 15 episodes - episode_reward: 8.467 [2.000, 13.000] - loss: 0.009 - mae: 1.345 - mean_q: 1.625 - ale.lives: 1.992
#
# Interval 40 (390000 steps performed)
# 10000/10000 [==============================] - 426s 43ms/step - reward: 0.0141
# 14 episodes - episode_reward: 9.714 [4.000, 22.000] - loss: 0.009 - mae: 1.346 - mean_q: 1.627 - ale.lives: 2.151
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 425s 42ms/step - reward: 0.0134
# 14 episodes - episode_reward: 9.143 [6.000, 23.000] - loss: 0.008 - mae: 1.338 - mean_q: 1.615 - ale.lives: 2.022
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 426s 43ms/step - reward: 0.0149
# 16 episodes - episode_reward: 9.875 [4.000, 24.000] - loss: 0.009 - mae: 1.350 - mean_q: 1.631 - ale.lives: 2.267
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 428s 43ms/step - reward: 0.0117
# 15 episodes - episode_reward: 7.600 [2.000, 19.000] - loss: 0.009 - mae: 1.352 - mean_q: 1.633 - ale.lives: 2.135
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 427s 43ms/step - reward: 0.0135
# 15 episodes - episode_reward: 8.533 [3.000, 22.000] - loss: 0.008 - mae: 1.368 - mean_q: 1.652 - ale.lives: 2.033
#
# Interval 45 (440000 steps performed)
# 10000/10000 [==============================] - 432s 43ms/step - reward: 0.0147
# 14 episodes - episode_reward: 10.429 [5.000, 20.000] - loss: 0.009 - mae: 1.360 - mean_q: 1.643 - ale.lives: 2.132
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 432s 43ms/step - reward: 0.0146
# 16 episodes - episode_reward: 8.938 [3.000, 19.000] - loss: 0.009 - mae: 1.354 - mean_q: 1.636 - ale.lives: 2.207
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 431s 43ms/step - reward: 0.0135
# 15 episodes - episode_reward: 9.800 [2.000, 20.000] - loss: 0.009 - mae: 1.346 - mean_q: 1.625 - ale.lives: 2.038
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 440s 44ms/step - reward: 0.0134
# 14 episodes - episode_reward: 9.357 [6.000, 17.000] - loss: 0.008 - mae: 1.361 - mean_q: 1.645 - ale.lives: 2.112
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 440s 44ms/step - reward: 0.0133
# 15 episodes - episode_reward: 9.000 [4.000, 12.000] - loss: 0.009 - mae: 1.383 - mean_q: 1.670 - ale.lives: 2.171
#
# Interval 50 (490000 steps performed)
# 10000/10000 [==============================] - 441s 44ms/step - reward: 0.0134
# 15 episodes - episode_reward: 8.800 [4.000, 15.000] - loss: 0.008 - mae: 1.377 - mean_q: 1.664 - ale.lives: 2.128
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 440s 44ms/step - reward: 0.0133
# 16 episodes - episode_reward: 8.750 [4.000, 23.000] - loss: 0.009 - mae: 1.369 - mean_q: 1.654 - ale.lives: 2.015
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 440s 44ms/step - reward: 0.0141
# 12 episodes - episode_reward: 10.000 [6.000, 16.000] - loss: 0.009 - mae: 1.366 - mean_q: 1.649 - ale.lives: 2.136
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 442s 44ms/step - reward: 0.0132
# 15 episodes - episode_reward: 9.533 [2.000, 21.000] - loss: 0.009 - mae: 1.357 - mean_q: 1.639 - ale.lives: 2.126
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 446s 45ms/step - reward: 0.0129
# 13 episodes - episode_reward: 10.385 [5.000, 16.000] - loss: 0.008 - mae: 1.365 - mean_q: 1.648 - ale.lives: 1.883
#
# Interval 55 (540000 steps performed)
# 10000/10000 [==============================] - 448s 45ms/step - reward: 0.0143
# 15 episodes - episode_reward: 9.667 [4.000, 19.000] - loss: 0.009 - mae: 1.362 - mean_q: 1.645 - ale.lives: 2.033
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 448s 45ms/step - reward: 0.0135
# 15 episodes - episode_reward: 9.067 [4.000, 17.000] - loss: 0.009 - mae: 1.363 - mean_q: 1.646 - ale.lives: 2.022
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 449s 45ms/step - reward: 0.0161
# 13 episodes - episode_reward: 12.462 [5.000, 19.000] - loss: 0.009 - mae: 1.368 - mean_q: 1.651 - ale.lives: 2.157
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 491s 49ms/step - reward: 0.0136
# 15 episodes - episode_reward: 8.800 [4.000, 19.000] - loss: 0.009 - mae: 1.377 - mean_q: 1.663 - ale.lives: 2.100
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 480s 48ms/step - reward: 0.0137
# 13 episodes - episode_reward: 9.846 [3.000, 15.000] - loss: 0.009 - mae: 1.377 - mean_q: 1.660 - ale.lives: 1.956
#
# Interval 60 (590000 steps performed)
# 10000/10000 [==============================] - 461s 46ms/step - reward: 0.0136
# 14 episodes - episode_reward: 10.143 [4.000, 22.000] - loss: 0.008 - mae: 1.358 - mean_q: 1.639 - ale.lives: 2.199
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 461s 46ms/step - reward: 0.0139
# 14 episodes - episode_reward: 10.429 [4.000, 18.000] - loss: 0.009 - mae: 1.352 - mean_q: 1.632 - ale.lives: 2.107
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 462s 46ms/step - reward: 0.0118
# 14 episodes - episode_reward: 8.286 [5.000, 15.000] - loss: 0.008 - mae: 1.344 - mean_q: 1.621 - ale.lives: 2.097
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 462s 46ms/step - reward: 0.0134
# 15 episodes - episode_reward: 8.800 [3.000, 14.000] - loss: 0.009 - mae: 1.343 - mean_q: 1.621 - ale.lives: 2.060
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 463s 46ms/step - reward: 0.0130
# 15 episodes - episode_reward: 7.800 [4.000, 13.000] - loss: 0.009 - mae: 1.349 - mean_q: 1.628 - ale.lives: 2.062
#
# Interval 65 (640000 steps performed)
# 10000/10000 [==============================] - 465s 47ms/step - reward: 0.0134
# 17 episodes - episode_reward: 8.765 [4.000, 19.000] - loss: 0.009 - mae: 1.340 - mean_q: 1.618 - ale.lives: 2.058
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 468s 47ms/step - reward: 0.0134
# 15 episodes - episode_reward: 8.933 [5.000, 15.000] - loss: 0.009 - mae: 1.337 - mean_q: 1.613 - ale.lives: 2.108
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 470s 47ms/step - reward: 0.0134
# 15 episodes - episode_reward: 8.800 [2.000, 13.000] - loss: 0.009 - mae: 1.348 - mean_q: 1.627 - ale.lives: 2.131
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 471s 47ms/step - reward: 0.0136
# 13 episodes - episode_reward: 10.769 [4.000, 17.000] - loss: 0.009 - mae: 1.361 - mean_q: 1.642 - ale.lives: 2.154
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 473s 47ms/step - reward: 0.0153
# 13 episodes - episode_reward: 11.077 [5.000, 26.000] - loss: 0.008 - mae: 1.344 - mean_q: 1.622 - ale.lives: 2.086
#
# Interval 70 (690000 steps performed)
# 10000/10000 [==============================] - 473s 47ms/step - reward: 0.0133
# 12 episodes - episode_reward: 11.833 [5.000, 24.000] - loss: 0.008 - mae: 1.336 - mean_q: 1.613 - ale.lives: 2.039
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 480s 48ms/step - reward: 0.0127
# 15 episodes - episode_reward: 7.933 [3.000, 21.000] - loss: 0.009 - mae: 1.343 - mean_q: 1.621 - ale.lives: 2.122
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 483s 48ms/step - reward: 0.0131
# 15 episodes - episode_reward: 9.267 [6.000, 13.000] - loss: 0.009 - mae: 1.359 - mean_q: 1.641 - ale.lives: 2.121
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 481s 48ms/step - reward: 0.0141
# 15 episodes - episode_reward: 9.400 [6.000, 18.000] - loss: 0.009 - mae: 1.366 - mean_q: 1.647 - ale.lives: 2.107
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 484s 48ms/step - reward: 0.0145
# 13 episodes - episode_reward: 11.154 [7.000, 19.000] - loss: 0.009 - mae: 1.363 - mean_q: 1.644 - ale.lives: 2.067
#
# Interval 75 (740000 steps performed)
# 10000/10000 [==============================] - 485s 48ms/step - reward: 0.0142
# 13 episodes - episode_reward: 10.538 [4.000, 17.000] - loss: 0.009 - mae: 1.360 - mean_q: 1.641 - ale.lives: 2.151
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 490s 49ms/step - reward: 0.0130
# 15 episodes - episode_reward: 8.267 [3.000, 14.000] - loss: 0.009 - mae: 1.356 - mean_q: 1.635 - ale.lives: 2.112
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 487s 49ms/step - reward: 0.0130
# 15 episodes - episode_reward: 9.400 [4.000, 24.000] - loss: 0.009 - mae: 1.347 - mean_q: 1.626 - ale.lives: 2.069
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 486s 49ms/step - reward: 0.0147
# 15 episodes - episode_reward: 9.267 [5.000, 14.000] - loss: 0.009 - mae: 1.336 - mean_q: 1.612 - ale.lives: 2.155
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 485s 48ms/step - reward: 0.0125
# 14 episodes - episode_reward: 9.071 [2.000, 12.000] - loss: 0.008 - mae: 1.335 - mean_q: 1.610 - ale.lives: 2.048
#
# Interval 80 (790000 steps performed)
# 10000/10000 [==============================] - 488s 49ms/step - reward: 0.0137
# 14 episodes - episode_reward: 9.857 [5.000, 17.000] - loss: 0.009 - mae: 1.338 - mean_q: 1.614 - ale.lives: 2.109
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 489s 49ms/step - reward: 0.0130
# 12 episodes - episode_reward: 11.250 [4.000, 23.000] - loss: 0.009 - mae: 1.345 - mean_q: 1.624 - ale.lives: 2.053
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 488s 49ms/step - reward: 0.0154
# 16 episodes - episode_reward: 9.625 [6.000, 18.000] - loss: 0.008 - mae: 1.344 - mean_q: 1.621 - ale.lives: 2.049
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 492s 49ms/step - reward: 0.0134
# 15 episodes - episode_reward: 8.933 [4.000, 18.000] - loss: 0.009 - mae: 1.351 - mean_q: 1.631 - ale.lives: 2.080
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 496s 50ms/step - reward: 0.0143
# 14 episodes - episode_reward: 9.786 [3.000, 18.000] - loss: 0.008 - mae: 1.357 - mean_q: 1.638 - ale.lives: 2.136
#
# Interval 85 (840000 steps performed)
# 10000/10000 [==============================] - 498s 50ms/step - reward: 0.0142
# 14 episodes - episode_reward: 10.357 [4.000, 18.000] - loss: 0.009 - mae: 1.362 - mean_q: 1.642 - ale.lives: 2.048
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 500s 50ms/step - reward: 0.0138
# 13 episodes - episode_reward: 10.615 [6.000, 20.000] - loss: 0.008 - mae: 1.356 - mean_q: 1.637 - ale.lives: 2.028
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 501s 50ms/step - reward: 0.0145
# 16 episodes - episode_reward: 8.875 [4.000, 17.000] - loss: 0.009 - mae: 1.349 - mean_q: 1.628 - ale.lives: 2.082
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 502s 50ms/step - reward: 0.0123
# 15 episodes - episode_reward: 8.467 [4.000, 15.000] - loss: 0.009 - mae: 1.346 - mean_q: 1.623 - ale.lives: 2.080
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 505s 50ms/step - reward: 0.0144
# 13 episodes - episode_reward: 11.077 [5.000, 22.000] - loss: 0.009 - mae: 1.339 - mean_q: 1.615 - ale.lives: 2.144
#
# Interval 90 (890000 steps performed)
# 10000/10000 [==============================] - 508s 51ms/step - reward: 0.0143
# 15 episodes - episode_reward: 9.267 [2.000, 23.000] - loss: 0.009 - mae: 1.332 - mean_q: 1.607 - ale.lives: 2.135
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 508s 51ms/step - reward: 0.0126
# 16 episodes - episode_reward: 8.250 [4.000, 13.000] - loss: 0.008 - mae: 1.336 - mean_q: 1.611 - ale.lives: 1.953
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 507s 51ms/step - reward: 0.0158
# 12 episodes - episode_reward: 12.667 [6.000, 23.000] - loss: 0.009 - mae: 1.338 - mean_q: 1.613 - ale.lives: 2.068
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 509s 51ms/step - reward: 0.0155
# 16 episodes - episode_reward: 9.688 [3.000, 19.000] - loss: 0.009 - mae: 1.336 - mean_q: 1.612 - ale.lives: 2.156
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 511s 51ms/step - reward: 0.0133
# 15 episodes - episode_reward: 8.933 [2.000, 16.000] - loss: 0.009 - mae: 1.352 - mean_q: 1.630 - ale.lives: 2.030
#
# Interval 95 (940000 steps performed)
# 10000/10000 [==============================] - 511s 51ms/step - reward: 0.0140
# 15 episodes - episode_reward: 8.667 [2.000, 17.000] - loss: 0.008 - mae: 1.363 - mean_q: 1.643 - ale.lives: 2.188
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 513s 51ms/step - reward: 0.0126
# 12 episodes - episode_reward: 11.417 [2.000, 20.000] - loss: 0.008 - mae: 1.350 - mean_q: 1.627 - ale.lives: 2.176
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 516s 52ms/step - reward: 0.0146
# 14 episodes - episode_reward: 10.714 [4.000, 24.000] - loss: 0.008 - mae: 1.332 - mean_q: 1.607 - ale.lives: 1.975
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 518s 52ms/step - reward: 0.0157
# 14 episodes - episode_reward: 10.786 [3.000, 19.000] - loss: 0.009 - mae: 1.327 - mean_q: 1.601 - ale.lives: 2.088
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 522s 52ms/step - reward: 0.0142
# 14 episodes - episode_reward: 9.786 [5.000, 17.000] - loss: 0.009 - mae: 1.340 - mean_q: 1.617 - ale.lives: 1.969
#
# Interval 100 (990000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0137
# 18 episodes - episode_reward: 7.889 [4.000, 14.000] - loss: 0.009 - mae: 1.338 - mean_q: 1.614 - ale.lives: 2.097
#
# Interval 101 (1000000 steps performed)
# 10000/10000 [==============================] - 522s 52ms/step - reward: 0.0150
# 14 episodes - episode_reward: 11.000 [6.000, 19.000] - loss: 0.008 - mae: 1.334 - mean_q: 1.609 - ale.lives: 1.992
#
# Interval 102 (1010000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0141
# 14 episodes - episode_reward: 9.857 [3.000, 19.000] - loss: 0.009 - mae: 1.327 - mean_q: 1.600 - ale.lives: 2.083
#
# Interval 103 (1020000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0135
# 14 episodes - episode_reward: 9.286 [4.000, 18.000] - loss: 0.008 - mae: 1.337 - mean_q: 1.613 - ale.lives: 2.041
#
# Interval 104 (1030000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0126
# 12 episodes - episode_reward: 11.000 [5.000, 18.000] - loss: 0.009 - mae: 1.363 - mean_q: 1.645 - ale.lives: 2.198
#
# Interval 105 (1040000 steps performed)
# 10000/10000 [==============================] - 525s 53ms/step - reward: 0.0129
# 16 episodes - episode_reward: 8.062 [4.000, 18.000] - loss: 0.009 - mae: 1.363 - mean_q: 1.644 - ale.lives: 2.100
#
# Interval 106 (1050000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0134
# 16 episodes - episode_reward: 8.500 [4.000, 17.000] - loss: 0.009 - mae: 1.363 - mean_q: 1.643 - ale.lives: 2.207
#
# Interval 107 (1060000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0133
# 15 episodes - episode_reward: 8.533 [5.000, 14.000] - loss: 0.008 - mae: 1.361 - mean_q: 1.641 - ale.lives: 2.086
#
# Interval 108 (1070000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0131
# 15 episodes - episode_reward: 8.800 [4.000, 18.000] - loss: 0.009 - mae: 1.363 - mean_q: 1.644 - ale.lives: 2.122
#
# Interval 109 (1080000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0142
# 16 episodes - episode_reward: 8.688 [3.000, 12.000] - loss: 0.008 - mae: 1.353 - mean_q: 1.632 - ale.lives: 2.085
#
# Interval 110 (1090000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0148
# 13 episodes - episode_reward: 11.462 [5.000, 27.000] - loss: 0.009 - mae: 1.352 - mean_q: 1.630 - ale.lives: 2.030
#
# Interval 111 (1100000 steps performed)
# 10000/10000 [==============================] - 525s 52ms/step - reward: 0.0139
# 14 episodes - episode_reward: 10.214 [4.000, 20.000] - loss: 0.009 - mae: 1.350 - mean_q: 1.626 - ale.lives: 2.074
#
# Interval 112 (1110000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0140
# 15 episodes - episode_reward: 9.133 [3.000, 15.000] - loss: 0.008 - mae: 1.348 - mean_q: 1.625 - ale.lives: 2.126
#
# Interval 113 (1120000 steps performed)
# 10000/10000 [==============================] - 522s 52ms/step - reward: 0.0142
# 13 episodes - episode_reward: 10.615 [6.000, 19.000] - loss: 0.008 - mae: 1.338 - mean_q: 1.612 - ale.lives: 2.101
#
# Interval 114 (1130000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0154
# 13 episodes - episode_reward: 11.462 [4.000, 20.000] - loss: 0.009 - mae: 1.330 - mean_q: 1.603 - ale.lives: 2.064
#
# Interval 115 (1140000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0131
# 15 episodes - episode_reward: 9.533 [1.000, 18.000] - loss: 0.009 - mae: 1.347 - mean_q: 1.625 - ale.lives: 2.096
#
# Interval 116 (1150000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0142
# 14 episodes - episode_reward: 10.429 [3.000, 17.000] - loss: 0.008 - mae: 1.355 - mean_q: 1.634 - ale.lives: 2.024
#
# Interval 117 (1160000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0124
# 16 episodes - episode_reward: 7.688 [1.000, 15.000] - loss: 0.009 - mae: 1.354 - mean_q: 1.632 - ale.lives: 2.111
#
# Interval 118 (1170000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0146
# 13 episodes - episode_reward: 10.538 [4.000, 18.000] - loss: 0.009 - mae: 1.347 - mean_q: 1.624 - ale.lives: 2.034
#
# Interval 119 (1180000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0137
# 15 episodes - episode_reward: 9.067 [4.000, 14.000] - loss: 0.008 - mae: 1.363 - mean_q: 1.644 - ale.lives: 2.164
#
# Interval 120 (1190000 steps performed)
# 10000/10000 [==============================] - 522s 52ms/step - reward: 0.0133
# 14 episodes - episode_reward: 10.214 [3.000, 26.000] - loss: 0.008 - mae: 1.366 - mean_q: 1.647 - ale.lives: 2.066
#
# Interval 121 (1200000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0133
# 16 episodes - episode_reward: 7.750 [2.000, 13.000] - loss: 0.009 - mae: 1.380 - mean_q: 1.664 - ale.lives: 2.109
#
# Interval 122 (1210000 steps performed)
# 10000/10000 [==============================] - 522s 52ms/step - reward: 0.0149
# 15 episodes - episode_reward: 10.067 [2.000, 20.000] - loss: 0.009 - mae: 1.386 - mean_q: 1.670 - ale.lives: 2.080
#
# Interval 123 (1220000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0128
# 16 episodes - episode_reward: 8.500 [4.000, 14.000] - loss: 0.009 - mae: 1.379 - mean_q: 1.662 - ale.lives: 2.208
#
# Interval 124 (1230000 steps performed)
# 10000/10000 [==============================] - 523s 52ms/step - reward: 0.0149
# 15 episodes - episode_reward: 9.133 [4.000, 21.000] - loss: 0.009 - mae: 1.368 - mean_q: 1.649 - ale.lives: 2.218
#
# Interval 125 (1240000 steps performed)
# 10000/10000 [==============================] - 525s 52ms/step - reward: 0.0147
# 13 episodes - episode_reward: 12.077 [4.000, 31.000] - loss: 0.009 - mae: 1.366 - mean_q: 1.647 - ale.lives: 1.925
#
# Interval 126 (1250000 steps performed)
# 10000/10000 [==============================] - 526s 53ms/step - reward: 0.0139
# 14 episodes - episode_reward: 9.571 [6.000, 15.000] - loss: 0.009 - mae: 1.360 - mean_q: 1.639 - ale.lives: 2.215
#
# Interval 127 (1260000 steps performed)
# 10000/10000 [==============================] - 526s 53ms/step - reward: 0.0143
# 13 episodes - episode_reward: 11.000 [4.000, 20.000] - loss: 0.009 - mae: 1.345 - mean_q: 1.622 - ale.lives: 1.944
#
# Interval 128 (1270000 steps performed)
# 10000/10000 [==============================] - 525s 52ms/step - reward: 0.0148
# 16 episodes - episode_reward: 9.562 [5.000, 18.000] - loss: 0.009 - mae: 1.343 - mean_q: 1.620 - ale.lives: 2.083
#
# Interval 129 (1280000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0124
# 17 episodes - episode_reward: 7.294 [3.000, 12.000] - loss: 0.008 - mae: 1.341 - mean_q: 1.618 - ale.lives: 2.123
#
# Interval 130 (1290000 steps performed)
# 10000/10000 [==============================] - 525s 52ms/step - reward: 0.0145
# 14 episodes - episode_reward: 10.286 [2.000, 23.000] - loss: 0.009 - mae: 1.345 - mean_q: 1.621 - ale.lives: 2.188
#
# Interval 131 (1300000 steps performed)
# 10000/10000 [==============================] - 525s 53ms/step - reward: 0.0126
# 14 episodes - episode_reward: 8.500 [4.000, 13.000] - loss: 0.009 - mae: 1.363 - mean_q: 1.643 - ale.lives: 2.107
#
# Interval 132 (1310000 steps performed)
# 10000/10000 [==============================] - 623s 62ms/step - reward: 0.0153
# 14 episodes - episode_reward: 11.500 [5.000, 23.000] - loss: 0.009 - mae: 1.382 - mean_q: 1.667 - ale.lives: 2.137
#
# Interval 133 (1320000 steps performed)
# 10000/10000 [==============================] - 528s 53ms/step - reward: 0.0141
# 17 episodes - episode_reward: 8.118 [2.000, 18.000] - loss: 0.009 - mae: 1.387 - mean_q: 1.672 - ale.lives: 2.154
#
# Interval 134 (1330000 steps performed)
# 10000/10000 [==============================] - 528s 53ms/step - reward: 0.0124
# 15 episodes - episode_reward: 8.133 [5.000, 13.000] - loss: 0.009 - mae: 1.380 - mean_q: 1.663 - ale.lives: 2.102
#
# Interval 135 (1340000 steps performed)
# 10000/10000 [==============================] - 528s 53ms/step - reward: 0.0162
# 14 episodes - episode_reward: 11.143 [4.000, 28.000] - loss: 0.009 - mae: 1.380 - mean_q: 1.663 - ale.lives: 2.147
#
# Interval 136 (1350000 steps performed)
# 10000/10000 [==============================] - 527s 53ms/step - reward: 0.0134
# 15 episodes - episode_reward: 9.533 [3.000, 22.000] - loss: 0.009 - mae: 1.384 - mean_q: 1.667 - ale.lives: 2.054
#
# Interval 137 (1360000 steps performed)
# 10000/10000 [==============================] - 527s 53ms/step - reward: 0.0132
# 13 episodes - episode_reward: 10.154 [6.000, 15.000] - loss: 0.009 - mae: 1.375 - mean_q: 1.657 - ale.lives: 2.047
#
# Interval 138 (1370000 steps performed)
# 10000/10000 [==============================] - 527s 53ms/step - reward: 0.0141
# 15 episodes - episode_reward: 9.533 [4.000, 18.000] - loss: 0.009 - mae: 1.375 - mean_q: 1.657 - ale.lives: 2.160
#
# Interval 139 (1380000 steps performed)
# 10000/10000 [==============================] - 529s 53ms/step - reward: 0.0147
# 14 episodes - episode_reward: 10.143 [6.000, 20.000] - loss: 0.009 - mae: 1.385 - mean_q: 1.669 - ale.lives: 2.011
#
# Interval 140 (1390000 steps performed)
# 10000/10000 [==============================] - 527s 53ms/step - reward: 0.0133
# 17 episodes - episode_reward: 8.176 [3.000, 23.000] - loss: 0.009 - mae: 1.399 - mean_q: 1.686 - ale.lives: 2.018
#
# Interval 141 (1400000 steps performed)
# 10000/10000 [==============================] - 526s 53ms/step - reward: 0.0117
# 13 episodes - episode_reward: 8.615 [3.000, 18.000] - loss: 0.009 - mae: 1.389 - mean_q: 1.674 - ale.lives: 2.022
#
# Interval 142 (1410000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0126
# 13 episodes - episode_reward: 9.154 [6.000, 17.000] - loss: 0.009 - mae: 1.379 - mean_q: 1.662 - ale.lives: 2.027
#
# Interval 143 (1420000 steps performed)
# 10000/10000 [==============================] - 524s 52ms/step - reward: 0.0118
# 15 episodes - episode_reward: 8.533 [4.000, 16.000] - loss: 0.009 - mae: 1.355 - mean_q: 1.633 - ale.lives: 2.084
#
# Interval 144 (1430000 steps performed)
# 10000/10000 [==============================] - 525s 52ms/step - reward: 0.0138
# 14 episodes - episode_reward: 9.357 [5.000, 19.000] - loss: 0.009 - mae: 1.359 - mean_q: 1.639 - ale.lives: 2.050
#
# Interval 145 (1440000 steps performed)
# 10000/10000 [==============================] - 527s 53ms/step - reward: 0.0128
# 15 episodes - episode_reward: 9.200 [3.000, 21.000] - loss: 0.009 - mae: 1.355 - mean_q: 1.633 - ale.lives: 2.104
#
# Interval 146 (1450000 steps performed)
# 10000/10000 [==============================] - 526s 53ms/step - reward: 0.0143
# 12 episodes - episode_reward: 11.167 [5.000, 23.000] - loss: 0.009 - mae: 1.353 - mean_q: 1.631 - ale.lives: 1.978
#
# Interval 147 (1460000 steps performed)
# 10000/10000 [==============================] - 526s 53ms/step - reward: 0.0137
# 16 episodes - episode_reward: 9.062 [4.000, 17.000] - loss: 0.009 - mae: 1.351 - mean_q: 1.627 - ale.lives: 2.167
#
# Interval 148 (1470000 steps performed)
# 10000/10000 [==============================] - 527s 53ms/step - reward: 0.0131
# 16 episodes - episode_reward: 7.875 [4.000, 15.000] - loss: 0.009 - mae: 1.344 - mean_q: 1.620 - ale.lives: 2.091
#
# Interval 149 (1480000 steps performed)
# 10000/10000 [==============================] - 527s 53ms/step - reward: 0.0135
# 14 episodes - episode_reward: 9.286 [4.000, 16.000] - loss: 0.008 - mae: 1.347 - mean_q: 1.623 - ale.lives: 2.132
#
# Interval 150 (1490000 steps performed)
# 10000/10000 [==============================] - 528s 53ms/step - reward: 0.0145
# 14 episodes - episode_reward: 10.714 [4.000, 21.000] - loss: 0.009 - mae: 1.345 - mean_q: 1.621 - ale.lives: 2.166
#
# Interval 151 (1500000 steps performed)
# 10000/10000 [==============================] - 529s 53ms/step - reward: 0.0118
# 13 episodes - episode_reward: 9.308 [3.000, 15.000] - loss: 0.009 - mae: 1.349 - mean_q: 1.625 - ale.lives: 2.007
#
# Interval 152 (1510000 steps performed)
# 10000/10000 [==============================] - 528s 53ms/step - reward: 0.0133
# 15 episodes - episode_reward: 8.267 [5.000, 15.000] - loss: 0.009 - mae: 1.367 - mean_q: 1.647 - ale.lives: 2.132
#
# Interval 153 (1520000 steps performed)
# 10000/10000 [==============================] - 529s 53ms/step - reward: 0.0141
# 14 episodes - episode_reward: 10.643 [4.000, 25.000] - loss: 0.009 - mae: 1.380 - mean_q: 1.662 - ale.lives: 2.115
#
# Interval 154 (1530000 steps performed)
# 10000/10000 [==============================] - 528s 53ms/step - reward: 0.0134
# 17 episodes - episode_reward: 7.941 [4.000, 20.000] - loss: 0.009 - mae: 1.378 - mean_q: 1.661 - ale.lives: 2.100
#
# Interval 155 (1540000 steps performed)
# 10000/10000 [==============================] - 529s 53ms/step - reward: 0.0144
# 12 episodes - episode_reward: 11.667 [7.000, 19.000] - loss: 0.009 - mae: 1.370 - mean_q: 1.651 - ale.lives: 2.099
#
# Interval 156 (1550000 steps performed)
# 10000/10000 [==============================] - 530s 53ms/step - reward: 0.0155
# 14 episodes - episode_reward: 10.929 [6.000, 21.000] - loss: 0.009 - mae: 1.364 - mean_q: 1.644 - ale.lives: 2.153
#
# Interval 157 (1560000 steps performed)
# 10000/10000 [==============================] - 530s 53ms/step - reward: 0.0141
# 15 episodes - episode_reward: 9.867 [5.000, 20.000] - loss: 0.009 - mae: 1.369 - mean_q: 1.651 - ale.lives: 2.052
#
# Interval 158 (1570000 steps performed)
# 10000/10000 [==============================] - 532s 53ms/step - reward: 0.0121
# 14 episodes - episode_reward: 8.786 [4.000, 15.000] - loss: 0.009 - mae: 1.357 - mean_q: 1.636 - ale.lives: 2.114
#
# Interval 159 (1580000 steps performed)
# 10000/10000 [==============================] - 531s 53ms/step - reward: 0.0155
# 15 episodes - episode_reward: 10.000 [4.000, 20.000] - loss: 0.008 - mae: 1.348 - mean_q: 1.625 - ale.lives: 2.188
#
# Interval 160 (1590000 steps performed)
# 10000/10000 [==============================] - 530s 53ms/step - reward: 0.0118
# 16 episodes - episode_reward: 7.500 [3.000, 13.000] - loss: 0.008 - mae: 1.350 - mean_q: 1.626 - ale.lives: 2.060
#
# Interval 161 (1600000 steps performed)
# 10000/10000 [==============================] - 530s 53ms/step - reward: 0.0138
# 15 episodes - episode_reward: 8.867 [4.000, 15.000] - loss: 0.009 - mae: 1.357 - mean_q: 1.635 - ale.lives: 2.053
#
# Interval 162 (1610000 steps performed)
# 10000/10000 [==============================] - 527s 53ms/step - reward: 0.0133
# 14 episodes - episode_reward: 9.786 [3.000, 20.000] - loss: 0.009 - mae: 1.353 - mean_q: 1.630 - ale.lives: 2.189
#
# Interval 163 (1620000 steps performed)
# 10000/10000 [==============================] - 527s 53ms/step - reward: 0.0145
# 14 episodes - episode_reward: 10.286 [4.000, 16.000] - loss: 0.009 - mae: 1.363 - mean_q: 1.642 - ale.lives: 2.021
#
# Interval 164 (1630000 steps performed)
# 10000/10000 [==============================] - 528s 53ms/step - reward: 0.0126
# 12 episodes - episode_reward: 10.333 [5.000, 19.000] - loss: 0.008 - mae: 1.355 - mean_q: 1.633 - ale.lives: 2.145
#
# Interval 165 (1640000 steps performed)
# 10000/10000 [==============================] - 529s 53ms/step - reward: 0.0146
# 12 episodes - episode_reward: 12.500 [6.000, 27.000] - loss: 0.009 - mae: 1.341 - mean_q: 1.617 - ale.lives: 1.995
#
# Interval 166 (1650000 steps performed)
# 10000/10000 [==============================] - 530s 53ms/step - reward: 0.0148
# 14 episodes - episode_reward: 10.214 [4.000, 18.000] - loss: 0.009 - mae: 1.336 - mean_q: 1.610 - ale.lives: 2.091
#
# Interval 167 (1660000 steps performed)
# 10000/10000 [==============================] - 531s 53ms/step - reward: 0.0157
# 15 episodes - episode_reward: 10.600 [4.000, 19.000] - loss: 0.009 - mae: 1.341 - mean_q: 1.617 - ale.lives: 2.044
#
# Interval 168 (1670000 steps performed)
# 10000/10000 [==============================] - 532s 53ms/step - reward: 0.0148
# 14 episodes - episode_reward: 10.786 [5.000, 22.000] - loss: 0.009 - mae: 1.344 - mean_q: 1.618 - ale.lives: 2.038
#
# Interval 169 (1680000 steps performed)
# 10000/10000 [==============================] - 530s 53ms/step - reward: 0.0124
# 15 episodes - episode_reward: 7.933 [3.000, 13.000] - loss: 0.009 - mae: 1.350 - mean_q: 1.627 - ale.lives: 2.133
#
# Interval 170 (1690000 steps performed)
# 10000/10000 [==============================] - 531s 53ms/step - reward: 0.0143
# 14 episodes - episode_reward: 10.357 [6.000, 18.000] - loss: 0.009 - mae: 1.361 - mean_q: 1.640 - ale.lives: 2.089
#
# Interval 171 (1700000 steps performed)
# 10000/10000 [==============================] - 530s 53ms/step - reward: 0.0147
# 13 episodes - episode_reward: 11.769 [6.000, 17.000] - loss: 0.008 - mae: 1.366 - mean_q: 1.645 - ale.lives: 2.029
#
# Interval 172 (1710000 steps performed)
# 10000/10000 [==============================] - 531s 53ms/step - reward: 0.0129
# 15 episodes - episode_reward: 8.400 [4.000, 16.000] - loss: 0.008 - mae: 1.343 - mean_q: 1.618 - ale.lives: 2.089
#
# Interval 173 (1720000 steps performed)
# 10000/10000 [==============================] - 532s 53ms/step - reward: 0.0134
# 13 episodes - episode_reward: 10.000 [3.000, 24.000] - loss: 0.009 - mae: 1.331 - mean_q: 1.604 - ale.lives: 2.114
#
# Interval 174 (1730000 steps performed)
# 10000/10000 [==============================] - 531s 53ms/step - reward: 0.0120
# 16 episodes - episode_reward: 7.938 [4.000, 14.000] - loss: 0.009 - mae: 1.346 - mean_q: 1.622 - ale.lives: 2.013
#
# Interval 175 (1740000 steps performed)
# 10000/10000 [==============================] - 528s 53ms/step - reward: 0.0138
# done, took 82600.536 seconds

# %%
# Testing part to calculate the mean reward
weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
history = dqn.test(env, nb_episodes=10, visualize=False)
# Obtener media y desviación estandar de la recompensa de los episodios
recompensas = history.history.get('episode_reward', [])
print(f"Media de la recompensa obtenida en 10 episodios: {np.mean(np.array(recompensas))}")
print(f"Desviación estandar de la recompensa obtenida en 10 episodios: {np.std(np.array(recompensas))}")
# Out:
# Testing for 10 episodes ...
# Episode 1: reward: 17.000, steps: 968
# Episode 2: reward: 17.000, steps: 971
# Episode 3: reward: 17.000, steps: 965
# Episode 4: reward: 17.000, steps: 959
# Episode 5: reward: 17.000, steps: 951
# Episode 6: reward: 17.000, steps: 961
# Episode 7: reward: 17.000, steps: 952
# Episode 8: reward: 17.000, steps: 973
# Episode 9: reward: 17.000, steps: 976
# Episode 10: reward: 17.000, steps: 977
# Media de la recompensa obtenida en 10 episodios: 17.0
# Desviación estandar de la recompensa obtenida en 10 episodios: 0.0

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %% [markdown]
# ---

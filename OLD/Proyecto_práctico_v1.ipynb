# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: Gil Garcera, Javier
# *   Alumno 2: Palomares Mateo, Abel
# *   Alumno 3: Serrano López, Francisco Rubén
# *   Alumno 4: Vegas Romero, David

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/actividades/proyecto practico"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# We're running Colab
# Colab: mounting Google drive on  /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# Colab: making sure  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico  exists.
#
# Colab: Changing directory to  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico
# /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico
# Archivos en el directorio:
# []

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.12  #2.8
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.5.3
  # %pip install torch==2.0.1
  # %pip install agents==1.4.0
# Out:
# Requirement already satisfied: gym==0.17.3 in /usr/local/lib/python3.11/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.15.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.23.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Collecting git+https://github.com/Kojoley/atari-py.git
#   Cloning https://github.com/Kojoley/atari-py.git to /tmp/pip-req-build-cqze76cz
#   Running command git clone --filter=blob:none --quiet https://github.com/Kojoley/atari-py.git /tmp/pip-req-build-cqze76cz
#   Resolved https://github.com/Kojoley/atari-py.git to commit 86a1e05c0a95e9e6233c3a413521fdb34ca8a089
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from atari-py==1.2.2) (1.23.5)
# Requirement already satisfied: keras-rl2==1.0.5 in /usr/local/lib/python3.11/dist-packages (1.0.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.8.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.3.1)
# Requirement already satisfied: tensorflow==2.12 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.5.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.8.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.3.1)

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation, Flatten, Convolution2D, Permute, BatchNormalization
from tensorflow.keras.optimizers.legacy import Adam
import tensorflow.keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# Callback personalizado para guardar pesos cada 50.000 pasos
from keras.callbacks import Callback
import os

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        processed_batch = batch.astype('float32') / 255.
        return processed_batch

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
def build_model(nb_actions, input_shape, window_length):
    model = Sequential()
    model.add(Permute((2, 3, 1), input_shape=(window_length,) + input_shape))  # (4,84,84) → (84,84,4)

    model.add(Convolution2D(32, (8, 8), strides=(4, 4)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Convolution2D(64, (4, 4), strides=(2, 2)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Convolution2D(64, (3, 3), strides=(1, 1)))
    model.add(BatchNormalization())
    model.add(Activation('relu'))

    model.add(Flatten())
    model.add(Dense(256))  # antes 512
    model.add(Activation('relu'))
    model.add(Dense(nb_actions, activation='linear'))  # Output Q-values

    model.summary()
    return model

# %% [markdown]
# 2. Implementación de la solución DQN

# %%
model = build_model(nb_actions, INPUT_SHAPE, WINDOW_LENGTH)

# Memoria y política
memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

policy = LinearAnnealedPolicy(
    EpsGreedyQPolicy(),
    attr='eps',
    value_max=1.0,
    value_min=0.1,           # más exploración al final
    value_test=0.05,
    nb_steps=100000          # exploración más lenta
)

dqn = DQNAgent(
    model=model,
    nb_actions=nb_actions,
    policy=policy,
    memory=memory,
    processor=AtariProcessor(),
    nb_steps_warmup=10000,    # menos calentamiento
    gamma=0.995,              # decisiones más a largo plazo
    target_model_update=5000, # actualizaciones más frecuentes
    train_interval=4,
    delta_clip=1.0,
    enable_double_dqn=True,
    enable_dueling_network=True,
    dueling_type='avg',
    batch_size=32             # más estable
)

dqn.compile(Adam(learning_rate=0.00025), metrics=['mae'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.11/dist-packages/keras/layers/normalization/batch_normalization.py:581: _colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  permute (Permute)           (None, 84, 84, 4)         0
#
#  conv2d (Conv2D)             (None, 20, 20, 32)        8224
#
#  batch_normalization (BatchN  (None, 20, 20, 32)       128
#  ormalization)
#
#  activation (Activation)     (None, 20, 20, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 9, 9, 64)          32832
#
#  batch_normalization_1 (Batc  (None, 9, 9, 64)         256
#  hNormalization)
#
#  activation_1 (Activation)   (None, 9, 9, 64)          0
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 64)          36928
#
#  batch_normalization_2 (Batc  (None, 7, 7, 64)         256
#  hNormalization)
#
#  activation_2 (Activation)   (None, 7, 7, 64)          0
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 256)               803072
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dense_1 (Dense)             (None, 6)                 1542
#
# =================================================================
# Total params: 883,238
# Trainable params: 882,918
# Non-trainable params: 320
# _________________________________________________________________

# %% [markdown]
# **CALLBACK PARA GUARDAR ENTRENAMIENTO**

# %%
from keras.callbacks import Callback
import os

class SaveModelCallback(Callback):
    def __init__(self, dqn, prefix='dqn_model', interval=50000):
        super().__init__()
        self.dqn = dqn
        self.prefix = prefix
        self.interval = interval
        self.steps = 0

    def on_step_end(self, step, logs={}):
        self.steps += 1
        if self.steps % self.interval == 0:
            filename = f'{self.prefix}_{self.steps}_steps.h5'
            print(f"\n[Guardando modelo completo en {filename}]")
            self.dqn.model.save(filename)  # ← guarda todo: arquitectura + pesos + optimizer

# %% [markdown]
# **ENTRENAMIENTO**

# %%
save_model_callback = SaveModelCallback(dqn, prefix='dqn_model', interval=50000)

dqn.fit(
    env,
    nb_steps=1750000,
    log_interval=10000,
    callbacks=[save_model_callback]
)
# Out:
# Training for 1750000 steps ...
# Interval 1 (0 steps performed)
#     1/10000 [..............................] - ETA: 27:34 - reward: 0.0000e+00
# /usr/local/lib/python3.11/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 40s 4ms/step - reward: 0.0142
# 14 episodes - episode_reward: 9.643 [5.000, 17.000] - ale.lives: 2.143
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 311s 31ms/step - reward: 0.0146
# 13 episodes - episode_reward: 11.385 [6.000, 26.000] - loss: 0.014 - mae: 0.050 - mean_q: 0.070 - mean_eps: 0.865 - ale.lives: 2.149
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 310s 31ms/step - reward: 0.0152
# 12 episodes - episode_reward: 12.583 [6.000, 22.000] - loss: 0.008 - mae: 0.065 - mean_q: 0.083 - mean_eps: 0.775 - ale.lives: 2.068
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 314s 31ms/step - reward: 0.0145
# 16 episodes - episode_reward: 9.125 [2.000, 16.000] - loss: 0.008 - mae: 0.090 - mean_q: 0.109 - mean_eps: 0.685 - ale.lives: 2.099
#
# Interval 5 (40000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0137
# [Guardando modelo completo en dqn_model_50000_steps.h5]
# 10000/10000 [==============================] - 312s 31ms/step - reward: 0.0137
# 14 episodes - episode_reward: 10.143 [2.000, 24.000] - loss: 0.008 - mae: 0.115 - mean_q: 0.138 - mean_eps: 0.595 - ale.lives: 1.913
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 311s 31ms/step - reward: 0.0153
# 14 episodes - episode_reward: 10.929 [1.000, 22.000] - loss: 0.008 - mae: 0.143 - mean_q: 0.172 - mean_eps: 0.505 - ale.lives: 2.020
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 310s 31ms/step - reward: 0.0153
# 11 episodes - episode_reward: 13.545 [6.000, 26.000] - loss: 0.008 - mae: 0.171 - mean_q: 0.205 - mean_eps: 0.415 - ale.lives: 2.013
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 311s 31ms/step - reward: 0.0131
# 11 episodes - episode_reward: 12.000 [6.000, 20.000] - loss: 0.008 - mae: 0.198 - mean_q: 0.238 - mean_eps: 0.325 - ale.lives: 1.889
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 311s 31ms/step - reward: 0.0162
# 12 episodes - episode_reward: 12.583 [7.000, 18.000] - loss: 0.008 - mae: 0.228 - mean_q: 0.273 - mean_eps: 0.235 - ale.lives: 1.895
#
# Interval 10 (90000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0143
# [Guardando modelo completo en dqn_model_100000_steps.h5]
# 10000/10000 [==============================] - 311s 31ms/step - reward: 0.0143
# 11 episodes - episode_reward: 13.818 [5.000, 22.000] - loss: 0.008 - mae: 0.250 - mean_q: 0.300 - mean_eps: 0.145 - ale.lives: 1.984
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 310s 31ms/step - reward: 0.0139
# 8 episodes - episode_reward: 16.250 [12.000, 23.000] - loss: 0.008 - mae: 0.265 - mean_q: 0.319 - mean_eps: 0.100 - ale.lives: 2.082
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 311s 31ms/step - reward: 0.0150
# 11 episodes - episode_reward: 13.727 [2.000, 21.000] - loss: 0.008 - mae: 0.284 - mean_q: 0.341 - mean_eps: 0.100 - ale.lives: 2.076
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 311s 31ms/step - reward: 0.0148
# 10 episodes - episode_reward: 14.700 [8.000, 24.000] - loss: 0.008 - mae: 0.315 - mean_q: 0.379 - mean_eps: 0.100 - ale.lives: 1.957
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 312s 31ms/step - reward: 0.0175
# 12 episodes - episode_reward: 14.917 [5.000, 20.000] - loss: 0.009 - mae: 0.342 - mean_q: 0.411 - mean_eps: 0.100 - ale.lives: 2.011
#
# Interval 15 (140000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0167
# [Guardando modelo completo en dqn_model_150000_steps.h5]
# 10000/10000 [==============================] - 314s 31ms/step - reward: 0.0167
# 10 episodes - episode_reward: 16.500 [10.000, 25.000] - loss: 0.009 - mae: 0.356 - mean_q: 0.429 - mean_eps: 0.100 - ale.lives: 1.960
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 317s 32ms/step - reward: 0.0153
# 11 episodes - episode_reward: 14.455 [11.000, 17.000] - loss: 0.008 - mae: 0.391 - mean_q: 0.470 - mean_eps: 0.100 - ale.lives: 2.123
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 318s 32ms/step - reward: 0.0149
# 11 episodes - episode_reward: 13.818 [3.000, 20.000] - loss: 0.008 - mae: 0.410 - mean_q: 0.492 - mean_eps: 0.100 - ale.lives: 2.027
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 319s 32ms/step - reward: 0.0164
# 9 episodes - episode_reward: 16.444 [6.000, 32.000] - loss: 0.009 - mae: 0.435 - mean_q: 0.521 - mean_eps: 0.100 - ale.lives: 2.059
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 322s 32ms/step - reward: 0.0198
# 12 episodes - episode_reward: 17.167 [10.000, 23.000] - loss: 0.009 - mae: 0.470 - mean_q: 0.564 - mean_eps: 0.100 - ale.lives: 2.035
#
# Interval 20 (190000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0155
# [Guardando modelo completo en dqn_model_200000_steps.h5]
# 10000/10000 [==============================] - 321s 32ms/step - reward: 0.0155
# 10 episodes - episode_reward: 16.400 [14.000, 22.000] - loss: 0.009 - mae: 0.489 - mean_q: 0.588 - mean_eps: 0.100 - ale.lives: 1.812
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 325s 32ms/step - reward: 0.0150
# 11 episodes - episode_reward: 12.727 [2.000, 24.000] - loss: 0.009 - mae: 0.506 - mean_q: 0.608 - mean_eps: 0.100 - ale.lives: 1.939
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0166
# 11 episodes - episode_reward: 15.545 [3.000, 30.000] - loss: 0.009 - mae: 0.528 - mean_q: 0.634 - mean_eps: 0.100 - ale.lives: 2.100
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 328s 33ms/step - reward: 0.0175
# 11 episodes - episode_reward: 15.818 [3.000, 26.000] - loss: 0.009 - mae: 0.536 - mean_q: 0.643 - mean_eps: 0.100 - ale.lives: 2.075
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 326s 33ms/step - reward: 0.0159
# 12 episodes - episode_reward: 13.083 [6.000, 24.000] - loss: 0.008 - mae: 0.565 - mean_q: 0.677 - mean_eps: 0.100 - ale.lives: 2.082
#
# Interval 25 (240000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0180
# [Guardando modelo completo en dqn_model_250000_steps.h5]
# 10000/10000 [==============================] - 330s 33ms/step - reward: 0.0180
# 13 episodes - episode_reward: 13.000 [10.000, 18.000] - loss: 0.009 - mae: 0.575 - mean_q: 0.689 - mean_eps: 0.100 - ale.lives: 2.133
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 329s 33ms/step - reward: 0.0176
# 10 episodes - episode_reward: 18.700 [9.000, 26.000] - loss: 0.009 - mae: 0.599 - mean_q: 0.718 - mean_eps: 0.100 - ale.lives: 2.010
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 331s 33ms/step - reward: 0.0138
# 11 episodes - episode_reward: 12.909 [5.000, 28.000] - loss: 0.010 - mae: 0.626 - mean_q: 0.751 - mean_eps: 0.100 - ale.lives: 1.853
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 333s 33ms/step - reward: 0.0158
# 11 episodes - episode_reward: 14.364 [6.000, 20.000] - loss: 0.010 - mae: 0.651 - mean_q: 0.783 - mean_eps: 0.100 - ale.lives: 1.925
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 337s 34ms/step - reward: 0.0133
# 9 episodes - episode_reward: 14.667 [10.000, 21.000] - loss: 0.010 - mae: 0.654 - mean_q: 0.784 - mean_eps: 0.100 - ale.lives: 2.166
#
# Interval 30 (290000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0153
# [Guardando modelo completo en dqn_model_300000_steps.h5]
# 10000/10000 [==============================] - 340s 34ms/step - reward: 0.0153
# 11 episodes - episode_reward: 14.091 [9.000, 21.000] - loss: 0.009 - mae: 0.683 - mean_q: 0.820 - mean_eps: 0.100 - ale.lives: 1.990
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 340s 34ms/step - reward: 0.0158
# 11 episodes - episode_reward: 14.182 [6.000, 25.000] - loss: 0.010 - mae: 0.698 - mean_q: 0.837 - mean_eps: 0.100 - ale.lives: 1.979
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 340s 34ms/step - reward: 0.0175
# 12 episodes - episode_reward: 14.500 [6.000, 22.000] - loss: 0.010 - mae: 0.709 - mean_q: 0.850 - mean_eps: 0.100 - ale.lives: 2.021
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 342s 34ms/step - reward: 0.0172
# 12 episodes - episode_reward: 14.583 [6.000, 27.000] - loss: 0.010 - mae: 0.741 - mean_q: 0.889 - mean_eps: 0.100 - ale.lives: 2.017
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 344s 34ms/step - reward: 0.0165
# 11 episodes - episode_reward: 14.909 [6.000, 20.000] - loss: 0.010 - mae: 0.769 - mean_q: 0.924 - mean_eps: 0.100 - ale.lives: 2.054
#
# Interval 35 (340000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0154
# [Guardando modelo completo en dqn_model_350000_steps.h5]
# 10000/10000 [==============================] - 345s 34ms/step - reward: 0.0154
# 12 episodes - episode_reward: 12.000 [6.000, 19.000] - loss: 0.010 - mae: 0.790 - mean_q: 0.948 - mean_eps: 0.100 - ale.lives: 1.963
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 344s 34ms/step - reward: 0.0167
# 12 episodes - episode_reward: 14.667 [7.000, 19.000] - loss: 0.010 - mae: 0.800 - mean_q: 0.961 - mean_eps: 0.100 - ale.lives: 2.034
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 345s 34ms/step - reward: 0.0141
# 10 episodes - episode_reward: 14.100 [3.000, 24.000] - loss: 0.010 - mae: 0.803 - mean_q: 0.964 - mean_eps: 0.100 - ale.lives: 1.814
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 364s 36ms/step - reward: 0.0169
# 12 episodes - episode_reward: 13.583 [6.000, 19.000] - loss: 0.010 - mae: 0.826 - mean_q: 0.991 - mean_eps: 0.100 - ale.lives: 1.924
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 358s 36ms/step - reward: 0.0161
# 12 episodes - episode_reward: 13.917 [5.000, 32.000] - loss: 0.010 - mae: 0.862 - mean_q: 1.036 - mean_eps: 0.100 - ale.lives: 2.022
#
# Interval 40 (390000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0155
# [Guardando modelo completo en dqn_model_400000_steps.h5]
# 10000/10000 [==============================] - 388s 39ms/step - reward: 0.0155
# 12 episodes - episode_reward: 13.250 [8.000, 21.000] - loss: 0.011 - mae: 0.885 - mean_q: 1.063 - mean_eps: 0.100 - ale.lives: 1.972
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 383s 38ms/step - reward: 0.0169
# 12 episodes - episode_reward: 13.750 [6.000, 20.000] - loss: 0.011 - mae: 0.892 - mean_q: 1.071 - mean_eps: 0.100 - ale.lives: 2.043
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 386s 39ms/step - reward: 0.0168
# 13 episodes - episode_reward: 13.000 [3.000, 22.000] - loss: 0.012 - mae: 0.915 - mean_q: 1.101 - mean_eps: 0.100 - ale.lives: 2.051
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 385s 38ms/step - reward: 0.0143
# 12 episodes - episode_reward: 11.833 [7.000, 17.000] - loss: 0.013 - mae: 0.935 - mean_q: 1.125 - mean_eps: 0.100 - ale.lives: 1.974
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 386s 39ms/step - reward: 0.0151
# 10 episodes - episode_reward: 15.300 [10.000, 22.000] - loss: 0.013 - mae: 0.955 - mean_q: 1.149 - mean_eps: 0.100 - ale.lives: 1.789
#
# Interval 45 (440000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0162
# [Guardando modelo completo en dqn_model_450000_steps.h5]
# 10000/10000 [==============================] - 386s 39ms/step - reward: 0.0162
# 9 episodes - episode_reward: 17.444 [8.000, 32.000] - loss: 0.014 - mae: 0.984 - mean_q: 1.183 - mean_eps: 0.100 - ale.lives: 1.973
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 370s 37ms/step - reward: 0.0157
# 9 episodes - episode_reward: 17.778 [13.000, 23.000] - loss: 0.013 - mae: 0.993 - mean_q: 1.192 - mean_eps: 0.100 - ale.lives: 2.062
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 365s 37ms/step - reward: 0.0151
# 10 episodes - episode_reward: 14.400 [8.000, 20.000] - loss: 0.020 - mae: 1.037 - mean_q: 1.249 - mean_eps: 0.100 - ale.lives: 2.159
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 361s 36ms/step - reward: 0.0147
# 12 episodes - episode_reward: 12.583 [3.000, 22.000] - loss: 0.018 - mae: 1.036 - mean_q: 1.248 - mean_eps: 0.100 - ale.lives: 2.065
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 377s 38ms/step - reward: 0.0135
# 11 episodes - episode_reward: 12.727 [8.000, 20.000] - loss: 0.018 - mae: 1.061 - mean_q: 1.280 - mean_eps: 0.100 - ale.lives: 1.914
#
# Interval 50 (490000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0128
# [Guardando modelo completo en dqn_model_500000_steps.h5]
# 10000/10000 [==============================] - 376s 38ms/step - reward: 0.0128
# 12 episodes - episode_reward: 11.000 [5.000, 18.000] - loss: 0.019 - mae: 1.070 - mean_q: 1.288 - mean_eps: 0.100 - ale.lives: 1.912
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 366s 37ms/step - reward: 0.0123
# 12 episodes - episode_reward: 10.083 [2.000, 20.000] - loss: 0.015 - mae: 1.082 - mean_q: 1.299 - mean_eps: 0.100 - ale.lives: 2.277
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 369s 37ms/step - reward: 0.0160
# 9 episodes - episode_reward: 16.778 [5.000, 28.000] - loss: 0.022 - mae: 1.132 - mean_q: 1.364 - mean_eps: 0.100 - ale.lives: 1.866
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 369s 37ms/step - reward: 0.0163
# 12 episodes - episode_reward: 14.417 [5.000, 21.000] - loss: 0.017 - mae: 1.118 - mean_q: 1.343 - mean_eps: 0.100 - ale.lives: 2.018
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 372s 37ms/step - reward: 0.0152
# 12 episodes - episode_reward: 12.833 [6.000, 20.000] - loss: 0.021 - mae: 1.139 - mean_q: 1.370 - mean_eps: 0.100 - ale.lives: 1.966
#
# Interval 55 (540000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0139
# [Guardando modelo completo en dqn_model_550000_steps.h5]
# 10000/10000 [==============================] - 373s 37ms/step - reward: 0.0140
# 10 episodes - episode_reward: 13.200 [6.000, 25.000] - loss: 0.020 - mae: 1.110 - mean_q: 1.333 - mean_eps: 0.100 - ale.lives: 2.014
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 376s 38ms/step - reward: 0.0157
# 11 episodes - episode_reward: 13.727 [4.000, 20.000] - loss: 0.019 - mae: 1.107 - mean_q: 1.331 - mean_eps: 0.100 - ale.lives: 2.137
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 382s 38ms/step - reward: 0.0149
# 10 episodes - episode_reward: 15.900 [10.000, 25.000] - loss: 0.024 - mae: 1.145 - mean_q: 1.377 - mean_eps: 0.100 - ale.lives: 2.097
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 384s 38ms/step - reward: 0.0123
# 9 episodes - episode_reward: 11.778 [5.000, 18.000] - loss: 0.019 - mae: 1.141 - mean_q: 1.373 - mean_eps: 0.100 - ale.lives: 2.034
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 386s 39ms/step - reward: 0.0159
# 10 episodes - episode_reward: 16.300 [4.000, 24.000] - loss: 0.019 - mae: 1.133 - mean_q: 1.366 - mean_eps: 0.100 - ale.lives: 1.901
#
# Interval 60 (590000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0164
# [Guardando modelo completo en dqn_model_600000_steps.h5]
# 10000/10000 [==============================] - 385s 38ms/step - reward: 0.0164
# 11 episodes - episode_reward: 15.364 [6.000, 27.000] - loss: 0.032 - mae: 1.155 - mean_q: 1.389 - mean_eps: 0.100 - ale.lives: 2.117
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 384s 38ms/step - reward: 0.0149
# 14 episodes - episode_reward: 10.929 [5.000, 16.000] - loss: 0.023 - mae: 1.167 - mean_q: 1.402 - mean_eps: 0.100 - ale.lives: 1.881
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 385s 39ms/step - reward: 0.0143
# 10 episodes - episode_reward: 14.900 [11.000, 18.000] - loss: 0.024 - mae: 1.154 - mean_q: 1.387 - mean_eps: 0.100 - ale.lives: 1.900
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 387s 39ms/step - reward: 0.0170
# 11 episodes - episode_reward: 15.455 [8.000, 27.000] - loss: 0.025 - mae: 1.180 - mean_q: 1.418 - mean_eps: 0.100 - ale.lives: 1.935
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 390s 39ms/step - reward: 0.0155
# 11 episodes - episode_reward: 12.182 [4.000, 20.000] - loss: 0.055 - mae: 1.274 - mean_q: 1.536 - mean_eps: 0.100 - ale.lives: 2.042
#
# Interval 65 (640000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0184
# [Guardando modelo completo en dqn_model_650000_steps.h5]
# 10000/10000 [==============================] - 392s 39ms/step - reward: 0.0184
# 13 episodes - episode_reward: 15.538 [5.000, 28.000] - loss: 0.040 - mae: 1.265 - mean_q: 1.523 - mean_eps: 0.100 - ale.lives: 2.065
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 398s 40ms/step - reward: 0.0145
# 10 episodes - episode_reward: 14.800 [7.000, 20.000] - loss: 0.037 - mae: 1.239 - mean_q: 1.490 - mean_eps: 0.100 - ale.lives: 1.998
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 398s 40ms/step - reward: 0.0139
# 10 episodes - episode_reward: 12.400 [6.000, 18.000] - loss: 0.073 - mae: 1.390 - mean_q: 1.689 - mean_eps: 0.100 - ale.lives: 1.913
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 401s 40ms/step - reward: 0.0143
# 10 episodes - episode_reward: 13.500 [7.000, 24.000] - loss: 0.105 - mae: 1.482 - mean_q: 1.794 - mean_eps: 0.100 - ale.lives: 2.031
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 401s 40ms/step - reward: 0.0177
# 10 episodes - episode_reward: 18.800 [14.000, 27.000] - loss: 0.106 - mae: 1.455 - mean_q: 1.756 - mean_eps: 0.100 - ale.lives: 1.982
#
# Interval 70 (690000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0158
# [Guardando modelo completo en dqn_model_700000_steps.h5]
# 10000/10000 [==============================] - 404s 40ms/step - reward: 0.0158
# 10 episodes - episode_reward: 16.900 [6.000, 34.000] - loss: 0.123 - mae: 1.497 - mean_q: 1.809 - mean_eps: 0.100 - ale.lives: 1.989
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 409s 41ms/step - reward: 0.0139
# 12 episodes - episode_reward: 11.583 [5.000, 17.000] - loss: 0.177 - mae: 1.738 - mean_q: 2.128 - mean_eps: 0.100 - ale.lives: 1.994
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 411s 41ms/step - reward: 0.0157
# 11 episodes - episode_reward: 13.545 [5.000, 26.000] - loss: 0.179 - mae: 1.579 - mean_q: 1.911 - mean_eps: 0.100 - ale.lives: 2.143
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 413s 41ms/step - reward: 0.0127
# 12 episodes - episode_reward: 10.750 [3.000, 17.000] - loss: 0.285 - mae: 1.872 - mean_q: 2.278 - mean_eps: 0.100 - ale.lives: 1.974
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 409s 41ms/step - reward: 0.0172
# 10 episodes - episode_reward: 18.100 [8.000, 29.000] - loss: 0.181 - mae: 1.694 - mean_q: 2.063 - mean_eps: 0.100 - ale.lives: 1.977
#
# Interval 75 (740000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0135
# [Guardando modelo completo en dqn_model_750000_steps.h5]
# 10000/10000 [==============================] - 413s 41ms/step - reward: 0.0135
# 10 episodes - episode_reward: 13.000 [3.000, 20.000] - loss: 0.451 - mae: 2.261 - mean_q: 2.788 - mean_eps: 0.100 - ale.lives: 2.074
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 420s 42ms/step - reward: 0.0129
# 11 episodes - episode_reward: 11.091 [3.000, 24.000] - loss: 0.745 - mae: 2.458 - mean_q: 3.008 - mean_eps: 0.100 - ale.lives: 1.918
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 424s 42ms/step - reward: 0.0164
# 11 episodes - episode_reward: 15.455 [6.000, 26.000] - loss: 0.523 - mae: 2.182 - mean_q: 2.662 - mean_eps: 0.100 - ale.lives: 2.104
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 419s 42ms/step - reward: 0.0167
# 11 episodes - episode_reward: 15.727 [9.000, 21.000] - loss: 0.501 - mae: 2.129 - mean_q: 2.573 - mean_eps: 0.100 - ale.lives: 2.063
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 421s 42ms/step - reward: 0.0137
# 13 episodes - episode_reward: 10.385 [2.000, 20.000] - loss: 1.010 - mae: 2.651 - mean_q: 3.201 - mean_eps: 0.100 - ale.lives: 2.041
#
# Interval 80 (790000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0127
# [Guardando modelo completo en dqn_model_800000_steps.h5]
# 10000/10000 [==============================] - 422s 42ms/step - reward: 0.0127
# 12 episodes - episode_reward: 10.417 [3.000, 21.000] - loss: 1.963 - mae: 4.032 - mean_q: 4.943 - mean_eps: 0.100 - ale.lives: 2.008
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 425s 42ms/step - reward: 0.0146
# 13 episodes - episode_reward: 10.538 [3.000, 21.000] - loss: 2.248 - mae: 3.697 - mean_q: 4.381 - mean_eps: 0.100 - ale.lives: 2.038
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 428s 43ms/step - reward: 0.0141
# 11 episodes - episode_reward: 13.545 [6.000, 21.000] - loss: 1.103 - mae: 3.018 - mean_q: 3.670 - mean_eps: 0.100 - ale.lives: 1.898
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 431s 43ms/step - reward: 0.0169
# 12 episodes - episode_reward: 14.167 [6.000, 22.000] - loss: 1.442 - mae: 2.883 - mean_q: 3.382 - mean_eps: 0.100 - ale.lives: 1.924
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 432s 43ms/step - reward: 0.0130
# 11 episodes - episode_reward: 11.909 [5.000, 24.000] - loss: 1.097 - mae: 2.896 - mean_q: 3.480 - mean_eps: 0.100 - ale.lives: 1.994
#
# Interval 85 (840000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0128
# [Guardando modelo completo en dqn_model_850000_steps.h5]
# 10000/10000 [==============================] - 435s 43ms/step - reward: 0.0128
# 11 episodes - episode_reward: 10.545 [5.000, 17.000] - loss: 1.976 - mae: 3.292 - mean_q: 3.806 - mean_eps: 0.100 - ale.lives: 1.993
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 439s 44ms/step - reward: 0.0164
# 10 episodes - episode_reward: 16.100 [10.000, 23.000] - loss: 2.546 - mae: 3.792 - mean_q: 4.324 - mean_eps: 0.100 - ale.lives: 1.888
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 461s 46ms/step - reward: 0.0155
# 11 episodes - episode_reward: 15.364 [6.000, 26.000] - loss: 2.703 - mae: 4.412 - mean_q: 5.123 - mean_eps: 0.100 - ale.lives: 1.973
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 459s 46ms/step - reward: 0.0144
# 10 episodes - episode_reward: 13.200 [5.000, 18.000] - loss: 1.903 - mae: 3.972 - mean_q: 4.735 - mean_eps: 0.100 - ale.lives: 2.067
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 466s 47ms/step - reward: 0.0156
# 10 episodes - episode_reward: 16.300 [12.000, 23.000] - loss: 2.600 - mae: 4.069 - mean_q: 4.711 - mean_eps: 0.100 - ale.lives: 2.048
#
# Interval 90 (890000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0171
# [Guardando modelo completo en dqn_model_900000_steps.h5]
# 10000/10000 [==============================] - 468s 47ms/step - reward: 0.0171
# 10 episodes - episode_reward: 17.300 [9.000, 32.000] - loss: 3.955 - mae: 5.160 - mean_q: 5.886 - mean_eps: 0.100 - ale.lives: 1.925
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 470s 47ms/step - reward: 0.0134
# 11 episodes - episode_reward: 11.909 [8.000, 17.000] - loss: 4.081 - mae: 4.926 - mean_q: 5.477 - mean_eps: 0.100 - ale.lives: 1.901
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 470s 47ms/step - reward: 0.0167
# 11 episodes - episode_reward: 15.545 [10.000, 30.000] - loss: 3.857 - mae: 5.075 - mean_q: 5.736 - mean_eps: 0.100 - ale.lives: 2.099
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 473s 47ms/step - reward: 0.0158
# 11 episodes - episode_reward: 14.545 [10.000, 27.000] - loss: 12.762 - mae: 10.180 - mean_q: 10.484 - mean_eps: 0.100 - ale.lives: 1.995
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 473s 47ms/step - reward: 0.0141
# 11 episodes - episode_reward: 12.818 [6.000, 20.000] - loss: 9.410 - mae: 7.419 - mean_q: 7.584 - mean_eps: 0.100 - ale.lives: 2.002
#
# Interval 95 (940000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0159
# [Guardando modelo completo en dqn_model_950000_steps.h5]
# 10000/10000 [==============================] - 480s 48ms/step - reward: 0.0160
# 10 episodes - episode_reward: 15.900 [6.000, 27.000] - loss: 6.666 - mae: 7.296 - mean_q: 7.982 - mean_eps: 0.100 - ale.lives: 1.888
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 494s 49ms/step - reward: 0.0138
# 13 episodes - episode_reward: 10.769 [6.000, 17.000] - loss: 9.475 - mae: 8.356 - mean_q: 8.795 - mean_eps: 0.100 - ale.lives: 2.033
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 505s 51ms/step - reward: 0.0124
# 11 episodes - episode_reward: 10.909 [3.000, 16.000] - loss: 7.254 - mae: 7.305 - mean_q: 7.741 - mean_eps: 0.100 - ale.lives: 2.081
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 497s 50ms/step - reward: 0.0181
# 12 episodes - episode_reward: 14.750 [7.000, 21.000] - loss: 16.472 - mae: 13.216 - mean_q: 13.451 - mean_eps: 0.100 - ale.lives: 2.039
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 488s 49ms/step - reward: 0.0183
# 13 episodes - episode_reward: 14.462 [8.000, 21.000] - loss: 15.227 - mae: 11.333 - mean_q: 11.394 - mean_eps: 0.100 - ale.lives: 2.075
#
# Interval 100 (990000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0125
# [Guardando modelo completo en dqn_model_1000000_steps.h5]
# 10000/10000 [==============================] - 486s 49ms/step - reward: 0.0125
# 10 episodes - episode_reward: 13.100 [6.000, 24.000] - loss: 16.013 - mae: 13.183 - mean_q: 13.884 - mean_eps: 0.100 - ale.lives: 1.954
#
# Interval 101 (1000000 steps performed)
# 10000/10000 [==============================] - 489s 49ms/step - reward: 0.0157
# 11 episodes - episode_reward: 13.727 [6.000, 24.000] - loss: 20.061 - mae: 15.304 - mean_q: 16.002 - mean_eps: 0.100 - ale.lives: 2.021
#
# Interval 102 (1010000 steps performed)
# 10000/10000 [==============================] - 489s 49ms/step - reward: 0.0178
# 11 episodes - episode_reward: 16.727 [11.000, 25.000] - loss: 12.060 - mae: 9.825 - mean_q: 10.545 - mean_eps: 0.100 - ale.lives: 2.058
#
# Interval 103 (1020000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0170
# 11 episodes - episode_reward: 13.818 [6.000, 22.000] - loss: 8.155 - mae: 9.316 - mean_q: 11.017 - mean_eps: 0.100 - ale.lives: 2.030
#
# Interval 104 (1030000 steps performed)
# 10000/10000 [==============================] - 484s 48ms/step - reward: 0.0162
# 12 episodes - episode_reward: 13.333 [6.000, 22.000] - loss: 9.989 - mae: 7.113 - mean_q: 7.534 - mean_eps: 0.100 - ale.lives: 2.013
#
# Interval 105 (1040000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0157
# [Guardando modelo completo en dqn_model_1050000_steps.h5]
# 10000/10000 [==============================] - 485s 48ms/step - reward: 0.0157
# 10 episodes - episode_reward: 15.300 [4.000, 25.000] - loss: 2.051 - mae: 4.320 - mean_q: 5.431 - mean_eps: 0.100 - ale.lives: 2.210
#
# Interval 106 (1050000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0171
# 12 episodes - episode_reward: 15.750 [4.000, 26.000] - loss: 1.681 - mae: 3.811 - mean_q: 4.800 - mean_eps: 0.100 - ale.lives: 2.045
#
# Interval 107 (1060000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0154
# 8 episodes - episode_reward: 18.750 [8.000, 26.000] - loss: 4.795 - mae: 4.672 - mean_q: 5.344 - mean_eps: 0.100 - ale.lives: 1.887
#
# Interval 108 (1070000 steps performed)
# 10000/10000 [==============================] - 477s 48ms/step - reward: 0.0166
# 11 episodes - episode_reward: 15.364 [7.000, 23.000] - loss: 3.411 - mae: 5.417 - mean_q: 6.831 - mean_eps: 0.100 - ale.lives: 2.031
#
# Interval 109 (1080000 steps performed)
# 10000/10000 [==============================] - 488s 49ms/step - reward: 0.0129
# 11 episodes - episode_reward: 12.000 [6.000, 17.000] - loss: 6.488 - mae: 8.709 - mean_q: 11.136 - mean_eps: 0.100 - ale.lives: 2.100
#
# Interval 110 (1090000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0143
# [Guardando modelo completo en dqn_model_1100000_steps.h5]
# 10000/10000 [==============================] - 486s 49ms/step - reward: 0.0143
# 10 episodes - episode_reward: 13.700 [8.000, 24.000] - loss: 3.486 - mae: 5.316 - mean_q: 6.783 - mean_eps: 0.100 - ale.lives: 2.036
#
# Interval 111 (1100000 steps performed)
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0159
# 12 episodes - episode_reward: 13.583 [10.000, 18.000] - loss: 5.535 - mae: 7.025 - mean_q: 8.834 - mean_eps: 0.100 - ale.lives: 1.902
#
# Interval 112 (1110000 steps performed)
# 10000/10000 [==============================] - 475s 47ms/step - reward: 0.0162
# 10 episodes - episode_reward: 15.700 [7.000, 34.000] - loss: 0.789 - mae: 3.675 - mean_q: 4.984 - mean_eps: 0.100 - ale.lives: 2.025
#
# Interval 113 (1120000 steps performed)
# 10000/10000 [==============================] - 474s 47ms/step - reward: 0.0162
# 12 episodes - episode_reward: 14.417 [6.000, 27.000] - loss: 11.389 - mae: 12.072 - mean_q: 15.369 - mean_eps: 0.100 - ale.lives: 1.962
#
# Interval 114 (1130000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0159
# 11 episodes - episode_reward: 13.091 [5.000, 23.000] - loss: 17.207 - mae: 14.916 - mean_q: 18.844 - mean_eps: 0.100 - ale.lives: 2.001
#
# Interval 115 (1140000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0157
# [Guardando modelo completo en dqn_model_1150000_steps.h5]
# 10000/10000 [==============================] - 488s 49ms/step - reward: 0.0157
# 10 episodes - episode_reward: 16.500 [12.000, 31.000] - loss: 34.935 - mae: 23.121 - mean_q: 27.475 - mean_eps: 0.100 - ale.lives: 1.907
#
# Interval 116 (1150000 steps performed)
# 10000/10000 [==============================] - 499s 50ms/step - reward: 0.0168
# 11 episodes - episode_reward: 14.545 [11.000, 23.000] - loss: 30.437 - mae: 19.385 - mean_q: 22.753 - mean_eps: 0.100 - ale.lives: 2.059
#
# Interval 117 (1160000 steps performed)
# 10000/10000 [==============================] - 497s 50ms/step - reward: 0.0171
# 12 episodes - episode_reward: 14.250 [6.000, 26.000] - loss: 35.426 - mae: 21.704 - mean_q: 25.545 - mean_eps: 0.100 - ale.lives: 1.999
#
# Interval 118 (1170000 steps performed)
# 10000/10000 [==============================] - 499s 50ms/step - reward: 0.0157
# 10 episodes - episode_reward: 16.600 [13.000, 19.000] - loss: 64.447 - mae: 36.592 - mean_q: 42.353 - mean_eps: 0.100 - ale.lives: 1.886
#
# Interval 119 (1180000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0132
# 9 episodes - episode_reward: 14.778 [10.000, 20.000] - loss: 68.260 - mae: 43.893 - mean_q: 53.923 - mean_eps: 0.100 - ale.lives: 1.993
#
# Interval 120 (1190000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0193
# [Guardando modelo completo en dqn_model_1200000_steps.h5]
# 10000/10000 [==============================] - 475s 48ms/step - reward: 0.0193
# 13 episodes - episode_reward: 14.846 [4.000, 21.000] - loss: 115.120 - mae: 53.886 - mean_q: 58.500 - mean_eps: 0.100 - ale.lives: 1.966
#
# Interval 121 (1200000 steps performed)
# 10000/10000 [==============================] - 482s 48ms/step - reward: 0.0174
# 11 episodes - episode_reward: 15.909 [11.000, 30.000] - loss: 129.099 - mae: 63.103 - mean_q: 70.330 - mean_eps: 0.100 - ale.lives: 1.973
#
# Interval 122 (1210000 steps performed)
# 10000/10000 [==============================] - 480s 48ms/step - reward: 0.0151
# 10 episodes - episode_reward: 15.300 [5.000, 26.000] - loss: 173.949 - mae: 97.968 - mean_q: 119.688 - mean_eps: 0.100 - ale.lives: 1.968
#
# Interval 123 (1220000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0172
# 10 episodes - episode_reward: 16.200 [8.000, 21.000] - loss: 182.309 - mae: 81.560 - mean_q: 89.079 - mean_eps: 0.100 - ale.lives: 2.060
#
# Interval 124 (1230000 steps performed)
# 10000/10000 [==============================] - 477s 48ms/step - reward: 0.0162
# 10 episodes - episode_reward: 17.100 [11.000, 24.000] - loss: 208.612 - mae: 92.076 - mean_q: 100.175 - mean_eps: 0.100 - ale.lives: 2.087
#
# Interval 125 (1240000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0159
# [Guardando modelo completo en dqn_model_1250000_steps.h5]
# 10000/10000 [==============================] - 475s 47ms/step - reward: 0.0159
# 11 episodes - episode_reward: 14.545 [6.000, 25.000] - loss: 243.516 - mae: 105.283 - mean_q: 116.273 - mean_eps: 0.100 - ale.lives: 1.950
#
# Interval 126 (1250000 steps performed)
# 10000/10000 [==============================] - 473s 47ms/step - reward: 0.0159
# 11 episodes - episode_reward: 12.909 [4.000, 26.000] - loss: 370.544 - mae: 144.493 - mean_q: 149.192 - mean_eps: 0.100 - ale.lives: 1.868
#
# Interval 127 (1260000 steps performed)
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0168
# 13 episodes - episode_reward: 13.538 [7.000, 20.000] - loss: 294.359 - mae: 123.539 - mean_q: 134.893 - mean_eps: 0.100 - ale.lives: 2.017
#
# Interval 128 (1270000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0164
# 11 episodes - episode_reward: 15.364 [7.000, 26.000] - loss: 456.440 - mae: 178.804 - mean_q: 190.792 - mean_eps: 0.100 - ale.lives: 1.987
#
# Interval 129 (1280000 steps performed)
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0177
# 10 episodes - episode_reward: 17.200 [10.000, 23.000] - loss: 412.808 - mae: 161.166 - mean_q: 174.065 - mean_eps: 0.100 - ale.lives: 1.988
#
# Interval 130 (1290000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0159
# [Guardando modelo completo en dqn_model_1300000_steps.h5]
# 10000/10000 [==============================] - 473s 47ms/step - reward: 0.0159
# 13 episodes - episode_reward: 13.077 [5.000, 19.000] - loss: 504.552 - mae: 185.701 - mean_q: 191.803 - mean_eps: 0.100 - ale.lives: 1.947
#
# Interval 131 (1300000 steps performed)
# 10000/10000 [==============================] - 472s 47ms/step - reward: 0.0137
# 9 episodes - episode_reward: 13.889 [5.000, 23.000] - loss: 769.540 - mae: 282.638 - mean_q: 291.125 - mean_eps: 0.100 - ale.lives: 1.855
#
# Interval 132 (1310000 steps performed)
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0169
# 10 episodes - episode_reward: 17.300 [9.000, 29.000] - loss: 868.775 - mae: 296.695 - mean_q: 288.185 - mean_eps: 0.100 - ale.lives: 1.855
#
# Interval 133 (1320000 steps performed)
# 10000/10000 [==============================] - 489s 49ms/step - reward: 0.0136
# 10 episodes - episode_reward: 14.000 [6.000, 22.000] - loss: 828.153 - mae: 308.228 - mean_q: 323.274 - mean_eps: 0.100 - ale.lives: 1.869
#
# Interval 134 (1330000 steps performed)
# 10000/10000 [==============================] - 481s 48ms/step - reward: 0.0171
# 11 episodes - episode_reward: 14.545 [11.000, 19.000] - loss: 765.925 - mae: 290.593 - mean_q: 309.834 - mean_eps: 0.100 - ale.lives: 1.963
#
# Interval 135 (1340000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0137
# [Guardando modelo completo en dqn_model_1350000_steps.h5]
# 10000/10000 [==============================] - 484s 48ms/step - reward: 0.0137
# 13 episodes - episode_reward: 11.308 [6.000, 20.000] - loss: 913.659 - mae: 337.301 - mean_q: 351.509 - mean_eps: 0.100 - ale.lives: 2.027
#
# Interval 136 (1350000 steps performed)
# 10000/10000 [==============================] - 481s 48ms/step - reward: 0.0138
# 9 episodes - episode_reward: 14.667 [7.000, 23.000] - loss: 887.765 - mae: 350.027 - mean_q: 393.669 - mean_eps: 0.100 - ale.lives: 2.140
#
# Interval 137 (1360000 steps performed)
# 10000/10000 [==============================] - 480s 48ms/step - reward: 0.0177
# 11 episodes - episode_reward: 16.545 [9.000, 21.000] - loss: 925.876 - mae: 356.463 - mean_q: 390.206 - mean_eps: 0.100 - ale.lives: 2.019
#
# Interval 138 (1370000 steps performed)
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0179
# 13 episodes - episode_reward: 14.154 [6.000, 23.000] - loss: 837.542 - mae: 355.187 - mean_q: 416.506 - mean_eps: 0.100 - ale.lives: 2.069
#
# Interval 139 (1380000 steps performed)
# 10000/10000 [==============================] - 475s 47ms/step - reward: 0.0142
# 9 episodes - episode_reward: 15.000 [6.000, 33.000] - loss: 1287.361 - mae: 473.011 - mean_q: 498.053 - mean_eps: 0.100 - ale.lives: 1.896
#
# Interval 140 (1390000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0174
# [Guardando modelo completo en dqn_model_1400000_steps.h5]
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0174
# 11 episodes - episode_reward: 15.364 [10.000, 34.000] - loss: 1168.874 - mae: 433.387 - mean_q: 463.823 - mean_eps: 0.100 - ale.lives: 2.060
#
# Interval 141 (1400000 steps performed)
# 10000/10000 [==============================] - 477s 48ms/step - reward: 0.0185
# 11 episodes - episode_reward: 16.000 [9.000, 22.000] - loss: 1813.370 - mae: 643.272 - mean_q: 654.057 - mean_eps: 0.100 - ale.lives: 1.944
#
# Interval 142 (1410000 steps performed)
# 10000/10000 [==============================] - 470s 47ms/step - reward: 0.0147
# 9 episodes - episode_reward: 15.889 [8.000, 33.000] - loss: 2197.820 - mae: 807.887 - mean_q: 850.513 - mean_eps: 0.100 - ale.lives: 1.873
#
# Interval 143 (1420000 steps performed)
# 10000/10000 [==============================] - 480s 48ms/step - reward: 0.0155
# 11 episodes - episode_reward: 15.182 [7.000, 29.000] - loss: 2073.204 - mae: 748.813 - mean_q: 781.914 - mean_eps: 0.100 - ale.lives: 1.993
#
# Interval 144 (1430000 steps performed)
# 10000/10000 [==============================] - 499s 50ms/step - reward: 0.0172
# 10 episodes - episode_reward: 18.600 [12.000, 30.000] - loss: 2175.728 - mae: 880.128 - mean_q: 992.596 - mean_eps: 0.100 - ale.lives: 1.936
#
# Interval 145 (1440000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0167
# [Guardando modelo completo en dqn_model_1450000_steps.h5]
# 10000/10000 [==============================] - 494s 49ms/step - reward: 0.0167
# 11 episodes - episode_reward: 14.545 [8.000, 20.000] - loss: 1836.065 - mae: 757.476 - mean_q: 860.068 - mean_eps: 0.100 - ale.lives: 1.987
#
# Interval 146 (1450000 steps performed)
# 10000/10000 [==============================] - 481s 48ms/step - reward: 0.0159
# 11 episodes - episode_reward: 15.091 [11.000, 21.000] - loss: 2135.820 - mae: 804.044 - mean_q: 857.378 - mean_eps: 0.100 - ale.lives: 1.885
#
# Interval 147 (1460000 steps performed)
# 10000/10000 [==============================] - 485s 48ms/step - reward: 0.0154
# 10 episodes - episode_reward: 14.100 [8.000, 19.000] - loss: 3039.686 - mae: 1154.807 - mean_q: 1258.193 - mean_eps: 0.100 - ale.lives: 2.188
#
# Interval 148 (1470000 steps performed)
# 10000/10000 [==============================] - 491s 49ms/step - reward: 0.0170
# 10 episodes - episode_reward: 17.800 [5.000, 29.000] - loss: 2633.900 - mae: 1062.939 - mean_q: 1205.574 - mean_eps: 0.100 - ale.lives: 2.101
#
# Interval 149 (1480000 steps performed)
# 10000/10000 [==============================] - 489s 49ms/step - reward: 0.0163
# 10 episodes - episode_reward: 15.900 [9.000, 22.000] - loss: 2194.421 - mae: 924.164 - mean_q: 1068.803 - mean_eps: 0.100 - ale.lives: 1.873
#
# Interval 150 (1490000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0132
# [Guardando modelo completo en dqn_model_1500000_steps.h5]
# 10000/10000 [==============================] - 483s 48ms/step - reward: 0.0132
# 11 episodes - episode_reward: 12.727 [4.000, 20.000] - loss: 3361.088 - mae: 1294.923 - mean_q: 1400.849 - mean_eps: 0.100 - ale.lives: 1.927
#
# Interval 151 (1500000 steps performed)
# 10000/10000 [==============================] - 475s 47ms/step - reward: 0.0158
# 11 episodes - episode_reward: 13.909 [7.000, 20.000] - loss: 3855.586 - mae: 1430.486 - mean_q: 1493.622 - mean_eps: 0.100 - ale.lives: 1.936
#
# Interval 152 (1510000 steps performed)
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0121
# 10 episodes - episode_reward: 12.200 [4.000, 17.000] - loss: 3820.683 - mae: 1556.750 - mean_q: 1729.810 - mean_eps: 0.100 - ale.lives: 1.825
#
# Interval 153 (1520000 steps performed)
# 10000/10000 [==============================] - 473s 47ms/step - reward: 0.0154
# 11 episodes - episode_reward: 13.818 [7.000, 21.000] - loss: 3436.744 - mae: 1501.619 - mean_q: 1737.417 - mean_eps: 0.100 - ale.lives: 2.035
#
# Interval 154 (1530000 steps performed)
# 10000/10000 [==============================] - 477s 48ms/step - reward: 0.0129
# 10 episodes - episode_reward: 13.100 [4.000, 32.000] - loss: 4014.049 - mae: 1963.075 - mean_q: 2420.911 - mean_eps: 0.100 - ale.lives: 1.969
#
# Interval 155 (1540000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0160
# [Guardando modelo completo en dqn_model_1550000_steps.h5]
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0160
# 11 episodes - episode_reward: 14.455 [7.000, 22.000] - loss: 4195.239 - mae: 1788.884 - mean_q: 2046.774 - mean_eps: 0.100 - ale.lives: 1.936
#
# Interval 156 (1550000 steps performed)
# 10000/10000 [==============================] - 479s 48ms/step - reward: 0.0139
# 12 episodes - episode_reward: 11.667 [4.000, 19.000] - loss: 4253.258 - mae: 1727.304 - mean_q: 1895.051 - mean_eps: 0.100 - ale.lives: 1.992
#
# Interval 157 (1560000 steps performed)
# 10000/10000 [==============================] - 486s 49ms/step - reward: 0.0171
# 10 episodes - episode_reward: 16.000 [9.000, 21.000] - loss: 5043.834 - mae: 1972.879 - mean_q: 2123.585 - mean_eps: 0.100 - ale.lives: 1.797
#
# Interval 158 (1570000 steps performed)
# 10000/10000 [==============================] - 482s 48ms/step - reward: 0.0159
# 12 episodes - episode_reward: 14.333 [9.000, 20.000] - loss: 5150.137 - mae: 2372.512 - mean_q: 2866.315 - mean_eps: 0.100 - ale.lives: 2.065
#
# Interval 159 (1580000 steps performed)
# 10000/10000 [==============================] - 489s 49ms/step - reward: 0.0137
# 11 episodes - episode_reward: 12.000 [5.000, 21.000] - loss: 5637.287 - mae: 2525.020 - mean_q: 2932.954 - mean_eps: 0.100 - ale.lives: 2.041
#
# Interval 160 (1590000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0146
# [Guardando modelo completo en dqn_model_1600000_steps.h5]
# 10000/10000 [==============================] - 483s 48ms/step - reward: 0.0147
# 12 episodes - episode_reward: 11.167 [4.000, 19.000] - loss: 4574.389 - mae: 2199.961 - mean_q: 2694.400 - mean_eps: 0.100 - ale.lives: 2.012
#
# Interval 161 (1600000 steps performed)
# 10000/10000 [==============================] - 475s 48ms/step - reward: 0.0108
# 10 episodes - episode_reward: 12.700 [3.000, 22.000] - loss: 9725.376 - mae: 3581.178 - mean_q: 3688.927 - mean_eps: 0.100 - ale.lives: 1.901
#
# Interval 162 (1610000 steps performed)
# 10000/10000 [==============================] - 475s 48ms/step - reward: 0.0157
# 11 episodes - episode_reward: 14.182 [6.000, 20.000] - loss: 8992.502 - mae: 3657.767 - mean_q: 4031.221 - mean_eps: 0.100 - ale.lives: 1.922
#
# Interval 163 (1620000 steps performed)
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0172
# 11 episodes - episode_reward: 15.000 [11.000, 19.000] - loss: 8046.543 - mae: 3786.381 - mean_q: 4540.231 - mean_eps: 0.100 - ale.lives: 2.047
#
# Interval 164 (1630000 steps performed)
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0136
# 12 episodes - episode_reward: 11.333 [5.000, 22.000] - loss: 10130.839 - mae: 4431.166 - mean_q: 5031.077 - mean_eps: 0.100 - ale.lives: 1.970
#
# Interval 165 (1640000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0152
# [Guardando modelo completo en dqn_model_1650000_steps.h5]
# 10000/10000 [==============================] - 478s 48ms/step - reward: 0.0152
# 11 episodes - episode_reward: 13.909 [7.000, 21.000] - loss: 7526.802 - mae: 3616.969 - mean_q: 4327.796 - mean_eps: 0.100 - ale.lives: 1.988
#
# Interval 166 (1650000 steps performed)
# 10000/10000 [==============================] - 477s 48ms/step - reward: 0.0181
# 13 episodes - episode_reward: 13.231 [4.000, 20.000] - loss: 8917.968 - mae: 3943.463 - mean_q: 4534.427 - mean_eps: 0.100 - ale.lives: 2.019
#
# Interval 167 (1660000 steps performed)
#  2861/10000 [=======>......................] - ETA: 5:44 - reward: 0.0136

# %%
# Cargar los mejores pesos (opcional si no se quiere continuar desde el último entrenado)
# dqn.load_weights('dqn_improved_1500000_weights.h5f')

# Evaluar durante 20 episodios
history = dqn.test(
    env,
    nb_episodes=20,
    visualize=True,
    verbose=2
)

# %%
# Testing part to calculate the mean reward
weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=False)
# Out:
# ---------------------------------------------------------------------------
# NotFoundError                             Traceback (most recent call last)
# /tmp/ipython-input-9-751549545.py in <cell line: 0>()
#       1 # Testing part to calculate the mean reward
#       2 weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
# ----> 3 dqn.load_weights(weights_filename)
#       4 dqn.test(env, nb_episodes=10, visualize=False)
#
# /usr/local/lib/python3.11/dist-packages/rl/agents/dqn.py in load_weights(self, filepath)
#     203
#     204     def load_weights(self, filepath):
# --> 205         self.model.load_weights(filepath)
#     206         self.update_target_model_hard()
#     207
#
# /usr/local/lib/python3.11/dist-packages/keras/engine/training_v1.py in load_weights(self, filepath, by_name, skip_mismatch)
#     220                     "with steps_per_run greater than 1."
#     221                 )
# --> 222         return super().load_weights(
#     223             filepath, by_name=by_name, skip_mismatch=skip_mismatch
#     224         )
#
# /usr/local/lib/python3.11/dist-packages/keras/utils/traceback_utils.py in error_handler(*args, **kwargs)
#      68             # To get the full stack trace, call:
#      69             # `tf.debugging.disable_traceback_filtering()`
# ---> 70             raise e.with_traceback(filtered_tb) from None
#      71         finally:
#      72             del filtered_tb
#
# /usr/local/lib/python3.11/dist-packages/tensorflow/python/training/py_checkpoint_reader.py in error_translator(e)
#      29       'Failed to find any '
#      30       'matching files for') in error_message:
# ---> 31     raise errors_impl.NotFoundError(None, None, error_message)
#      32   elif 'Sliced checkpoints are not supported' in error_message or (
#      33       'Data type '
#
# NotFoundError: Unsuccessful TensorSliceReader constructor: Failed to find any matching files for dqn_SpaceInvaders-v0_weights.h5f

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %% [markdown]
# ---

# %% [markdown]
# # Actividad - Proyecto práctico
#
#
# > La actividad se desarrollará en grupos pre-definidos de 2-3 alumnos. Se debe indicar los nombres en orden alfabético (de apellidos). Recordad que esta actividad se corresponde con un 30% de la nota final de la asignatura. Se debe entregar entregar el trabajo en la presente notebook.
# *   Alumno 1: Gil Garcera, Javier
# *   Alumno 2: Palomares Mateo, Abel
# *   Alumno 3: Serrano López, Francisco Rubén
# *   Alumno 4: Vegas Romero, David

# %% [markdown]
# ---
# ## **PARTE 1** - Instalación y requisitos previos
#
# > Las prácticas han sido preparadas para poder realizarse en el entorno de trabajo de Google Colab. Sin embargo, esta plataforma presenta ciertas incompatibilidades a la hora de visualizar la renderización en gym. Por ello, para obtener estas visualizaciones, se deberá trasladar el entorno de trabajo a local. Por ello, el presente dosier presenta instrucciones para poder trabajar en ambos entornos. Siga los siguientes pasos para un correcto funcionamiento:
# 1.   **LOCAL:** Preparar el enviroment, siguiendo las intrucciones detalladas en la sección *1.1.Preparar enviroment*.
# 2.  **AMBOS:** Modificar las variables "mount" y "drive_mount" a la carpeta de trabajo en drive en el caso de estar en Colab, y ejecturar la celda *1.2.Localizar entorno de trabajo*.
# 3. **COLAB:** se deberá ejecutar las celdas correspondientes al montaje de la carpeta de trabajo en Drive. Esta corresponde a la sección *1.3.Montar carpeta de datos local*.
# 4.  **AMBOS:** Instalar las librerías necesarias, siguiendo la sección *1.4.Instalar librerías necesarias*.

# %% [markdown]
# ---
# ### 1.1. Preparar enviroment (solo local)
#
#
#
# > Para preparar el entorno de trabajo en local, se han seguido los siguientes pasos:
# 1. En Windows, puede ser necesario instalar las C++ Build Tools. Para ello, siga los siguientes pasos: https://towardsdatascience.com/how-to-install-openai-gym-in-a-windows-environment-338969e24d30.
# 2. Instalar Anaconda
# 3. Siguiendo el código que se presenta comentado en la próxima celda: Crear un enviroment, cambiar la ruta de trabajo, e instalar librerías básicas.
#
#
# ```
# conda create --name miar_rl python=3.8
# conda activate miar_rl
# cd "PATH_TO_FOLDER"
# conda install git
# pip install jupyter
# ```
#
#
# 4. Abrir la notebook con *jupyter-notebook*.
#
#
#
# ```
# jupyter-notebook
# ```

# %% [markdown]
# ---
# ### 1.2. Localizar entorno de trabajo: Google colab o local

# %%
# ATENCIÓN!! Modificar ruta relativa a la práctica si es distinta (drive_root)
mount='/content/gdrive'
drive_root = mount + "/My Drive/08_MIAR/actividades/proyecto practico_v2"

try:
  from google.colab import drive
  IN_COLAB=True
except:
  IN_COLAB=False

# %% [markdown]
# ---
# ### 1.3. Montar carpeta de datos local (solo Colab)

# %%
# Switch to the directory on the Google Drive that you want to use
import os
if IN_COLAB:
  print("We're running Colab")

  if IN_COLAB:
    # Mount the Google Drive at mount
    print("Colab: mounting Google drive on ", mount)

    drive.mount(mount)

    # Create drive_root if it doesn't exist
    create_drive_root = True
    if create_drive_root:
      print("\nColab: making sure ", drive_root, " exists.")
      os.makedirs(drive_root, exist_ok=True)

    # Change to the directory
    print("\nColab: Changing directory to ", drive_root)
    # %cd $drive_root
# Verify we're in the correct working directory
# %pwd
print("Archivos en el directorio: ")
print(os.listdir())
# Out:
# We're running Colab
# Colab: mounting Google drive on  /content/gdrive
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
#
# Colab: making sure  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico_v2  exists.
#
# Colab: Changing directory to  /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico_v2
# /content/gdrive/My Drive/08_MIAR/actividades/proyecto practico_v2
# Archivos en el directorio:
# []

# %% [markdown]
# ---
# ### 1.4. Instalar librerías necesarias

# %%
if IN_COLAB:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install keras-rl2==1.0.5
  # %pip install tensorflow==2.12
else:
  # %pip install gym==0.17.3
  # %pip install git+https://github.com/Kojoley/atari-py.git
  # %pip install pyglet==1.5.0
  # %pip install h5py==3.1.0
  # %pip install Pillow==9.5.0
  # %pip install keras-rl2==1.0.5
  # %pip install Keras==2.2.4
  # %pip install tensorflow==2.12.1
  # %pip install torch==2.0.1
  # %pip install tensorflow-gpu==2.5.3
  # %pip install agents==1.4.0
# Out:
# Requirement already satisfied: gym==0.17.3 in /usr/local/lib/python3.11/dist-packages (0.17.3)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.15.3)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.23.5)
# Requirement already satisfied: pyglet<=1.5.0,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.5.0)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gym==0.17.3) (1.6.0)
# Requirement already satisfied: future in /usr/local/lib/python3.11/dist-packages (from pyglet<=1.5.0,>=1.4.0->gym==0.17.3) (1.0.0)
# Collecting git+https://github.com/Kojoley/atari-py.git
#   Cloning https://github.com/Kojoley/atari-py.git to /tmp/pip-req-build-k61_rqjl
#   Running command git clone --filter=blob:none --quiet https://github.com/Kojoley/atari-py.git /tmp/pip-req-build-k61_rqjl
#   Resolved https://github.com/Kojoley/atari-py.git to commit 86a1e05c0a95e9e6233c3a413521fdb34ca8a089
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from atari-py==1.2.2) (1.23.5)
# Requirement already satisfied: keras-rl2==1.0.5 in /usr/local/lib/python3.11/dist-packages (1.0.5)
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (from keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow->keras-rl2==1.0.5) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow->keras-rl2==1.0.5) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow->keras-rl2==1.0.5) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.8.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow->keras-rl2==1.0.5) (3.3.1)
# Requirement already satisfied: tensorflow==2.12 in /usr/local/lib/python3.11/dist-packages (2.12.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (25.2.10)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.2.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.73.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.14.0)
# Requirement already satisfied: jax>=0.3.15 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.4.30)
# Requirement already satisfied: keras<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (18.1.1)
# Requirement already satisfied: numpy<1.24,>=1.22 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.23.5)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.25.8)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.17.0)
# Requirement already satisfied: tensorboard<2.13,>=2.12 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.3)
# Requirement already satisfied: tensorflow-estimator<2.13,>=2.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (2.12.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (4.14.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow==2.12) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow==2.12) (0.45.1)
# Requirement already satisfied: jaxlib<=0.4.30,>=0.4.27 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.30)
# Requirement already satisfied: ml-dtypes>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (0.4.1)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.11/dist-packages (from jax>=0.3.15->tensorflow==2.12) (1.15.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.38.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.8.2)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (2.32.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.13,>=2.12->tensorflow==2.12) (3.1.3)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.0.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorboard<2.13,>=2.12->tensorflow==2.12) (2025.6.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.0.2)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.13,>=2.12->tensorflow==2.12) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard<2.13,>=2.12->tensorflow==2.12) (3.3.1)

# %% [markdown]
# ---
# ## **PARTE 2**. Enunciado
#
# Consideraciones a tener en cuenta:
#
# - El entorno sobre el que trabajaremos será _SpaceInvaders-v0_ y el algoritmo que usaremos será _DQN_.
#
# - Para nuestro ejercicio, el requisito mínimo será alcanzado cuando el agente consiga una **media de recompensa por encima de 20 puntos en modo test**. Por ello, esta media de la recompensa se calculará a partir del código de test en la última celda del notebook.
#
# Este proyecto práctico consta de tres partes:
#
# 1.   Implementar la red neuronal que se usará en la solución
# 2.   Implementar las distintas piezas de la solución DQN
# 3.   Justificar la respuesta en relación a los resultados obtenidos
#
# **Rúbrica**: Se valorará la originalidad en la solución aportada, así como la capacidad de discutir los resultados de forma detallada. El requisito mínimo servirá para aprobar la actividad, bajo premisa de que la discusión del resultado sera apropiada.
#
# IMPORTANTE:
#
# * Si no se consigue una puntuación óptima, responder sobre la mejor puntuación obtenida.
# * Para entrenamientos largos, recordad que podéis usar checkpoints de vuestros modelos para retomar los entrenamientos. En este caso, recordad cambiar los parámetros adecuadamente (sobre todo los relacionados con el proceso de exploración).
# * Se deberá entregar unicamente el notebook y los pesos del mejor modelo en un fichero .zip, de forma organizada.
# * Cada alumno deberá de subir la solución de forma individual.

# %% [markdown]
# ---
# ## **PARTE 3**. Desarrollo y preguntas

# %% [markdown]
# #### Importar librerías

# %%
from __future__ import division

from PIL import Image
import numpy as np
import gym

from keras.models import Sequential
from keras.layers import Dense, Activation, Flatten, Conv2D, Permute
from keras.optimizers import Adam
import keras.backend as K

from rl.agents.dqn import DQNAgent
from rl.policy import LinearAnnealedPolicy, BoltzmannQPolicy, EpsGreedyQPolicy
from rl.memory import SequentialMemory
from rl.core import Processor
from rl.callbacks import FileLogger, ModelIntervalCheckpoint

# %% [markdown]
# #### Configuración base

# %%
INPUT_SHAPE = (84, 84)
WINDOW_LENGTH = 4

env_name = 'SpaceInvaders-v0'
env = gym.make(env_name)

np.random.seed(123)
env.seed(123)
nb_actions = env.action_space.n

# %%
class AtariProcessor(Processor):
    def process_observation(self, observation):
        assert observation.ndim == 3  # (height, width, channel)
        img = Image.fromarray(observation)
        img = img.resize(INPUT_SHAPE).convert('L')
        processed_observation = np.array(img)
        assert processed_observation.shape == INPUT_SHAPE
        return processed_observation.astype('uint8')

    def process_state_batch(self, batch):
        # batch: (batch_size, window_length, height, width)
        # → lo convertimos a (batch_size, height, width, window_length)
        return batch.transpose(0, 2, 3, 1).astype('float32') / 255.

    def process_reward(self, reward):
        return np.clip(reward, -1., 1.)

# %% [markdown]
# * Hemos modificado la función `process_state_batch` para adaptar la forma del lote de datos al formato esperado por las capas convolucionales de Keras, que es (`batch, height, width, channels`). Esto es necesario porque usamos el formato por defecto `channels_last`, donde los 4 frames apilados deben colocarse en el último eje. Sin esta transposición, la red no puede procesar correctamente las entradas, lo que genera errores o un entrenamiento incorrecto.

# %% [markdown]
# 1. Implementación de la red neuronal

# %%
def build_model(nb_actions, input_shape, window_length):
    model = Sequential()

    input_shape = input_shape + (window_length,)

    model.add(Conv2D(32, (8, 8), strides=(4, 4), activation='relu', input_shape=input_shape))
    model.add(Conv2D(64, (4, 4), strides=(2, 2), activation='relu'))
    model.add(Conv2D(64, (3, 3), strides=(1, 1), activation='relu'))
    model.add(Flatten())
    model.add(Dense(512, activation='relu'))
    model.add(Dense(256, activation='relu'))
    model.add(Dense(nb_actions, activation='linear'))

    return model

# %% [markdown]
# 2. Implementación de la solución DQN

# %%
def build_agent(model, nb_actions):

    policy = LinearAnnealedPolicy(
        EpsGreedyQPolicy(),
        attr='eps',
        value_max=1.0,
        value_min=0.1,
        nb_steps=int(0.75 * 2000000),  # 75% del total
        value_test=0.05
        )

    memory = SequentialMemory(limit=1000000, window_length=WINDOW_LENGTH)

    dqn = DQNAgent(model=model,
                   memory=memory,
                   policy=policy,
                   nb_actions=nb_actions,
                   nb_steps_warmup=1000,
                   gamma=0.99,
                   target_model_update=10000,
                   train_interval=4,
                   delta_clip=1.0,
                   enable_double_dqn=True,
                   enable_dueling_network=True,
                   dueling_type='avg',
                   processor=AtariProcessor()
                   )
    return dqn

# %% [markdown]
# **Compilación y definición del callback para guardar el modelo**

# %%
from keras.callbacks import Callback
import os

class SaveModelCallback(Callback):
    def __init__(self, dqn, prefix='dqn_model', interval=50000):
        super().__init__()
        self.dqn = dqn
        self.prefix = prefix
        self.interval = interval
        self.steps = 0

    def on_step_end(self, step, logs={}):
        self.steps += 1
        if self.steps % self.interval == 0:
            filename = f'{self.prefix}_{self.steps}.h5'
            print(f"\nGuardando modelo en {filename}")
            self.dqn.model.save(filename)

# Crear callback
save_model_callback = SaveModelCallback(None, prefix='dqn_model', interval=50000)

# %% [markdown]
# **Entrenamiento del agente (Reanudándolo automáticamente desde el ultimo modelo guardado en caso de que se haya quedado a medias)**

# %%
import re

# Parámetros
TOTAL_STEPS = 2000000
MODEL_PREFIX = "dqn_model"
MODEL_DIR = "."  # Carpeta actual

# Buscar el último modelo guardado
def find_latest_model(prefix, directory):
    pattern = re.compile(rf"{re.escape(prefix)}_(\d+)\.h5")
    saved_models = []
    for fname in os.listdir(directory):
        match = pattern.match(fname)
        if match:
            saved_models.append((int(match.group(1)), os.path.join(directory, fname)))
    if saved_models:
        saved_models.sort(reverse=True)  # el más reciente primero
        return saved_models[0]  # (step, path)
    return None

# Crear modelo y agente
model = build_model(nb_actions, INPUT_SHAPE, WINDOW_LENGTH)
dqn = build_agent(model, nb_actions)

# Compilar antes de cargar pesos
dqn.compile(Adam(learning_rate=0.00025), metrics=['mae'])

# Cargar el modelo si existe y ajustar steps restantes
last_model = find_latest_model(MODEL_PREFIX, MODEL_DIR)
if last_model:
    last_step, model_path = last_model
    print(f"Cargando pesos desde: {model_path}")
    dqn.load_weights(model_path)  # ahora sí, después de compilar
    remaining_steps = TOTAL_STEPS - last_step
else:
    print("No se encontró ningún modelo anterior. Entrenando desde cero.")
    remaining_steps = TOTAL_STEPS

# Asignar callback
save_model_callback.dqn = dqn

# Entrenamiento
dqn.fit(env,
        nb_steps=remaining_steps,
        log_interval=10000,
        callbacks=[save_model_callback])

# Guardar pesos finales
dqn.save_weights("dqn_weights_final.h5", overwrite=True)
# Out:
# No se encontró ningún modelo anterior. Entrenando desde cero.
# Training for 2000000 steps ...
# Interval 1 (0 steps performed)
#     1/10000 [..............................] - ETA: 30:25 - reward: 0.0000e+00
# /usr/local/lib/python3.11/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
#   997/10000 [=>............................] - ETA: 39s - reward: 0.0120
# /usr/local/lib/python3.11/dist-packages/keras/engine/training_v1.py:2359: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   updates=self.state_updates,
# 10000/10000 [==============================] - 304s 30ms/step - reward: 0.0142
# 13 episodes - episode_reward: 9.692 [3.000, 20.000] - loss: 0.006 - mae: 0.020 - mean_q: 0.037 - mean_eps: 0.997 - ale.lives: 2.150
#
# Interval 2 (10000 steps performed)
# 10000/10000 [==============================] - 331s 33ms/step - reward: 0.0148
# 14 episodes - episode_reward: 11.286 [5.000, 27.000] - loss: 0.006 - mae: 0.039 - mean_q: 0.071 - mean_eps: 0.991 - ale.lives: 2.221
#
# Interval 3 (20000 steps performed)
# 10000/10000 [==============================] - 335s 33ms/step - reward: 0.0118
# 13 episodes - episode_reward: 9.077 [3.000, 19.000] - loss: 0.006 - mae: 0.057 - mean_q: 0.094 - mean_eps: 0.985 - ale.lives: 2.058
#
# Interval 4 (30000 steps performed)
# 10000/10000 [==============================] - 337s 34ms/step - reward: 0.0129
# 15 episodes - episode_reward: 8.933 [3.000, 18.000] - loss: 0.007 - mae: 0.088 - mean_q: 0.131 - mean_eps: 0.979 - ale.lives: 1.989
#
# Interval 5 (40000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0133
# Guardando modelo en dqn_model_50000.h5
# 10000/10000 [==============================] - 337s 34ms/step - reward: 0.0133
# 13 episodes - episode_reward: 9.846 [4.000, 15.000] - loss: 0.008 - mae: 0.116 - mean_q: 0.161 - mean_eps: 0.973 - ale.lives: 2.138
#
# Interval 6 (50000 steps performed)
# 10000/10000 [==============================] - 343s 34ms/step - reward: 0.0111
# 15 episodes - episode_reward: 7.800 [3.000, 12.000] - loss: 0.008 - mae: 0.150 - mean_q: 0.202 - mean_eps: 0.967 - ale.lives: 1.972
#
# Interval 7 (60000 steps performed)
# 10000/10000 [==============================] - 341s 34ms/step - reward: 0.0126
# 17 episodes - episode_reward: 7.412 [3.000, 16.000] - loss: 0.008 - mae: 0.184 - mean_q: 0.240 - mean_eps: 0.961 - ale.lives: 2.041
#
# Interval 8 (70000 steps performed)
# 10000/10000 [==============================] - 340s 34ms/step - reward: 0.0122
# 14 episodes - episode_reward: 8.357 [3.000, 15.000] - loss: 0.009 - mae: 0.219 - mean_q: 0.283 - mean_eps: 0.955 - ale.lives: 2.153
#
# Interval 9 (80000 steps performed)
# 10000/10000 [==============================] - 340s 34ms/step - reward: 0.0130
# 14 episodes - episode_reward: 9.000 [5.000, 16.000] - loss: 0.009 - mae: 0.238 - mean_q: 0.305 - mean_eps: 0.949 - ale.lives: 2.103
#
# Interval 10 (90000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0131
# Guardando modelo en dqn_model_100000.h5
# 10000/10000 [==============================] - 340s 34ms/step - reward: 0.0131
# 14 episodes - episode_reward: 9.857 [4.000, 17.000] - loss: 0.009 - mae: 0.260 - mean_q: 0.330 - mean_eps: 0.943 - ale.lives: 2.115
#
# Interval 11 (100000 steps performed)
# 10000/10000 [==============================] - 342s 34ms/step - reward: 0.0129
# 15 episodes - episode_reward: 8.333 [4.000, 14.000] - loss: 0.010 - mae: 0.284 - mean_q: 0.359 - mean_eps: 0.937 - ale.lives: 2.067
#
# Interval 12 (110000 steps performed)
# 10000/10000 [==============================] - 343s 34ms/step - reward: 0.0142
# 16 episodes - episode_reward: 8.438 [4.000, 24.000] - loss: 0.009 - mae: 0.299 - mean_q: 0.377 - mean_eps: 0.931 - ale.lives: 2.252
#
# Interval 13 (120000 steps performed)
# 10000/10000 [==============================] - 343s 34ms/step - reward: 0.0151
# 15 episodes - episode_reward: 10.333 [5.000, 18.000] - loss: 0.010 - mae: 0.312 - mean_q: 0.392 - mean_eps: 0.925 - ale.lives: 2.054
#
# Interval 14 (130000 steps performed)
# 10000/10000 [==============================] - 343s 34ms/step - reward: 0.0140
# 15 episodes - episode_reward: 9.933 [4.000, 24.000] - loss: 0.009 - mae: 0.331 - mean_q: 0.415 - mean_eps: 0.919 - ale.lives: 2.129
#
# Interval 15 (140000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0149
# Guardando modelo en dqn_model_150000.h5
# 10000/10000 [==============================] - 340s 34ms/step - reward: 0.0149
# 15 episodes - episode_reward: 9.933 [1.000, 21.000] - loss: 0.010 - mae: 0.360 - mean_q: 0.451 - mean_eps: 0.913 - ale.lives: 2.130
#
# Interval 16 (150000 steps performed)
# 10000/10000 [==============================] - 343s 34ms/step - reward: 0.0147
# 16 episodes - episode_reward: 8.750 [5.000, 21.000] - loss: 0.010 - mae: 0.369 - mean_q: 0.460 - mean_eps: 0.907 - ale.lives: 2.102
#
# Interval 17 (160000 steps performed)
# 10000/10000 [==============================] - 341s 34ms/step - reward: 0.0159
# 15 episodes - episode_reward: 11.067 [4.000, 28.000] - loss: 0.010 - mae: 0.400 - mean_q: 0.498 - mean_eps: 0.901 - ale.lives: 2.033
#
# Interval 18 (170000 steps performed)
# 10000/10000 [==============================] - 343s 34ms/step - reward: 0.0160
# 12 episodes - episode_reward: 13.000 [7.000, 22.000] - loss: 0.010 - mae: 0.433 - mean_q: 0.538 - mean_eps: 0.895 - ale.lives: 2.144
#
# Interval 19 (180000 steps performed)
# 10000/10000 [==============================] - 341s 34ms/step - reward: 0.0154
# 15 episodes - episode_reward: 10.533 [6.000, 17.000] - loss: 0.011 - mae: 0.459 - mean_q: 0.569 - mean_eps: 0.889 - ale.lives: 2.013
#
# Interval 20 (190000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0136
# Guardando modelo en dqn_model_200000.h5
# 10000/10000 [==============================] - 347s 35ms/step - reward: 0.0136
# 15 episodes - episode_reward: 8.667 [5.000, 14.000] - loss: 0.011 - mae: 0.481 - mean_q: 0.596 - mean_eps: 0.883 - ale.lives: 2.124
#
# Interval 21 (200000 steps performed)
# 10000/10000 [==============================] - 354s 35ms/step - reward: 0.0169
# 14 episodes - episode_reward: 11.929 [4.000, 28.000] - loss: 0.011 - mae: 0.497 - mean_q: 0.616 - mean_eps: 0.877 - ale.lives: 2.135
#
# Interval 22 (210000 steps performed)
# 10000/10000 [==============================] - 355s 35ms/step - reward: 0.0164
# 15 episodes - episode_reward: 10.867 [4.000, 20.000] - loss: 0.011 - mae: 0.523 - mean_q: 0.646 - mean_eps: 0.871 - ale.lives: 2.038
#
# Interval 23 (220000 steps performed)
# 10000/10000 [==============================] - 357s 36ms/step - reward: 0.0158
# 16 episodes - episode_reward: 10.062 [4.000, 20.000] - loss: 0.011 - mae: 0.538 - mean_q: 0.666 - mean_eps: 0.865 - ale.lives: 2.038
#
# Interval 24 (230000 steps performed)
# 10000/10000 [==============================] - 358s 36ms/step - reward: 0.0167
# 15 episodes - episode_reward: 11.067 [6.000, 27.000] - loss: 0.011 - mae: 0.563 - mean_q: 0.695 - mean_eps: 0.859 - ale.lives: 2.059
#
# Interval 25 (240000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0163
# Guardando modelo en dqn_model_250000.h5
# 10000/10000 [==============================] - 359s 36ms/step - reward: 0.0163
# 14 episodes - episode_reward: 12.143 [2.000, 25.000] - loss: 0.011 - mae: 0.580 - mean_q: 0.715 - mean_eps: 0.853 - ale.lives: 2.263
#
# Interval 26 (250000 steps performed)
# 10000/10000 [==============================] - 360s 36ms/step - reward: 0.0150
# 14 episodes - episode_reward: 10.071 [5.000, 29.000] - loss: 0.011 - mae: 0.600 - mean_q: 0.738 - mean_eps: 0.847 - ale.lives: 1.978
#
# Interval 27 (260000 steps performed)
# 10000/10000 [==============================] - 365s 36ms/step - reward: 0.0142
# 16 episodes - episode_reward: 8.875 [3.000, 20.000] - loss: 0.011 - mae: 0.626 - mean_q: 0.770 - mean_eps: 0.841 - ale.lives: 2.053
#
# Interval 28 (270000 steps performed)
# 10000/10000 [==============================] - 358s 36ms/step - reward: 0.0152
# 13 episodes - episode_reward: 11.538 [7.000, 18.000] - loss: 0.012 - mae: 0.661 - mean_q: 0.813 - mean_eps: 0.835 - ale.lives: 2.107
#
# Interval 29 (280000 steps performed)
# 10000/10000 [==============================] - 361s 36ms/step - reward: 0.0181
# 14 episodes - episode_reward: 13.286 [4.000, 28.000] - loss: 0.011 - mae: 0.669 - mean_q: 0.820 - mean_eps: 0.829 - ale.lives: 2.053
#
# Interval 30 (290000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0141
# Guardando modelo en dqn_model_300000.h5
# 10000/10000 [==============================] - 360s 36ms/step - reward: 0.0141
# 15 episodes - episode_reward: 9.533 [3.000, 16.000] - loss: 0.011 - mae: 0.687 - mean_q: 0.840 - mean_eps: 0.823 - ale.lives: 2.068
#
# Interval 31 (300000 steps performed)
# 10000/10000 [==============================] - 361s 36ms/step - reward: 0.0173
# 15 episodes - episode_reward: 11.667 [3.000, 29.000] - loss: 0.012 - mae: 0.733 - mean_q: 0.896 - mean_eps: 0.817 - ale.lives: 2.085
#
# Interval 32 (310000 steps performed)
# 10000/10000 [==============================] - 363s 36ms/step - reward: 0.0150
# 17 episodes - episode_reward: 8.765 [3.000, 22.000] - loss: 0.011 - mae: 0.737 - mean_q: 0.899 - mean_eps: 0.811 - ale.lives: 2.107
#
# Interval 33 (320000 steps performed)
# 10000/10000 [==============================] - 360s 36ms/step - reward: 0.0170
# 13 episodes - episode_reward: 12.846 [2.000, 27.000] - loss: 0.011 - mae: 0.750 - mean_q: 0.915 - mean_eps: 0.805 - ale.lives: 2.220
#
# Interval 34 (330000 steps performed)
# 10000/10000 [==============================] - 367s 37ms/step - reward: 0.0155
# 17 episodes - episode_reward: 9.471 [2.000, 17.000] - loss: 0.012 - mae: 0.777 - mean_q: 0.948 - mean_eps: 0.799 - ale.lives: 2.159
#
# Interval 35 (340000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0171
# Guardando modelo en dqn_model_350000.h5
# 10000/10000 [==============================] - 367s 37ms/step - reward: 0.0171
# 13 episodes - episode_reward: 12.538 [6.000, 25.000] - loss: 0.011 - mae: 0.795 - mean_q: 0.969 - mean_eps: 0.793 - ale.lives: 2.063
#
# Interval 36 (350000 steps performed)
# 10000/10000 [==============================] - 368s 37ms/step - reward: 0.0141
# 15 episodes - episode_reward: 9.667 [3.000, 21.000] - loss: 0.013 - mae: 0.814 - mean_q: 0.991 - mean_eps: 0.787 - ale.lives: 2.180
#
# Interval 37 (360000 steps performed)
# 10000/10000 [==============================] - 368s 37ms/step - reward: 0.0158
# 14 episodes - episode_reward: 10.357 [5.000, 16.000] - loss: 0.013 - mae: 0.860 - mean_q: 1.046 - mean_eps: 0.781 - ale.lives: 2.091
#
# Interval 38 (370000 steps performed)
# 10000/10000 [==============================] - 369s 37ms/step - reward: 0.0164
# 16 episodes - episode_reward: 10.938 [3.000, 24.000] - loss: 0.013 - mae: 0.882 - mean_q: 1.071 - mean_eps: 0.775 - ale.lives: 2.160
#
# Interval 39 (380000 steps performed)
# 10000/10000 [==============================] - 373s 37ms/step - reward: 0.0155
# 13 episodes - episode_reward: 12.000 [7.000, 18.000] - loss: 0.014 - mae: 0.946 - mean_q: 1.147 - mean_eps: 0.769 - ale.lives: 2.045
#
# Interval 40 (390000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0164
# Guardando modelo en dqn_model_400000.h5
# 10000/10000 [==============================] - 378s 38ms/step - reward: 0.0164
# 15 episodes - episode_reward: 10.933 [3.000, 21.000] - loss: 0.014 - mae: 0.949 - mean_q: 1.151 - mean_eps: 0.763 - ale.lives: 2.120
#
# Interval 41 (400000 steps performed)
# 10000/10000 [==============================] - 378s 38ms/step - reward: 0.0186
# 15 episodes - episode_reward: 11.933 [6.000, 23.000] - loss: 0.013 - mae: 0.955 - mean_q: 1.159 - mean_eps: 0.757 - ale.lives: 2.027
#
# Interval 42 (410000 steps performed)
# 10000/10000 [==============================] - 381s 38ms/step - reward: 0.0157
# 17 episodes - episode_reward: 9.882 [2.000, 18.000] - loss: 0.014 - mae: 0.961 - mean_q: 1.165 - mean_eps: 0.751 - ale.lives: 2.103
#
# Interval 43 (420000 steps performed)
# 10000/10000 [==============================] - 384s 38ms/step - reward: 0.0170
# 16 episodes - episode_reward: 10.250 [4.000, 21.000] - loss: 0.014 - mae: 0.987 - mean_q: 1.196 - mean_eps: 0.745 - ale.lives: 2.183
#
# Interval 44 (430000 steps performed)
# 10000/10000 [==============================] - 386s 39ms/step - reward: 0.0181
# 12 episodes - episode_reward: 14.667 [8.000, 28.000] - loss: 0.015 - mae: 1.012 - mean_q: 1.225 - mean_eps: 0.739 - ale.lives: 2.063
#
# Interval 45 (440000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0172
# Guardando modelo en dqn_model_450000.h5
# 10000/10000 [==============================] - 390s 39ms/step - reward: 0.0172
# 14 episodes - episode_reward: 12.714 [7.000, 21.000] - loss: 0.014 - mae: 1.046 - mean_q: 1.268 - mean_eps: 0.733 - ale.lives: 2.159
#
# Interval 46 (450000 steps performed)
# 10000/10000 [==============================] - 387s 39ms/step - reward: 0.0178
# 15 episodes - episode_reward: 11.600 [5.000, 20.000] - loss: 0.015 - mae: 1.065 - mean_q: 1.290 - mean_eps: 0.727 - ale.lives: 1.950
#
# Interval 47 (460000 steps performed)
# 10000/10000 [==============================] - 388s 39ms/step - reward: 0.0201
# 15 episodes - episode_reward: 13.000 [5.000, 27.000] - loss: 0.016 - mae: 1.085 - mean_q: 1.314 - mean_eps: 0.721 - ale.lives: 2.202
#
# Interval 48 (470000 steps performed)
# 10000/10000 [==============================] - 393s 39ms/step - reward: 0.0177
# 15 episodes - episode_reward: 11.467 [4.000, 25.000] - loss: 0.015 - mae: 1.103 - mean_q: 1.336 - mean_eps: 0.715 - ale.lives: 2.087
#
# Interval 49 (480000 steps performed)
# 10000/10000 [==============================] - 397s 40ms/step - reward: 0.0187
# 16 episodes - episode_reward: 12.938 [8.000, 27.000] - loss: 0.017 - mae: 1.131 - mean_q: 1.370 - mean_eps: 0.709 - ale.lives: 2.045
#
# Interval 50 (490000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0178
# Guardando modelo en dqn_model_500000.h5
# 10000/10000 [==============================] - 396s 40ms/step - reward: 0.0178
# 15 episodes - episode_reward: 11.867 [6.000, 24.000] - loss: 0.017 - mae: 1.131 - mean_q: 1.369 - mean_eps: 0.703 - ale.lives: 2.063
#
# Interval 51 (500000 steps performed)
# 10000/10000 [==============================] - 393s 39ms/step - reward: 0.0192
# 14 episodes - episode_reward: 13.429 [8.000, 21.000] - loss: 0.017 - mae: 1.145 - mean_q: 1.386 - mean_eps: 0.697 - ale.lives: 2.091
#
# Interval 52 (510000 steps performed)
# 10000/10000 [==============================] - 397s 40ms/step - reward: 0.0165
# 15 episodes - episode_reward: 11.067 [3.000, 17.000] - loss: 0.016 - mae: 1.157 - mean_q: 1.400 - mean_eps: 0.691 - ale.lives: 2.186
#
# Interval 53 (520000 steps performed)
# 10000/10000 [==============================] - 398s 40ms/step - reward: 0.0192
# 15 episodes - episode_reward: 12.733 [2.000, 24.000] - loss: 0.015 - mae: 1.165 - mean_q: 1.408 - mean_eps: 0.685 - ale.lives: 2.181
#
# Interval 54 (530000 steps performed)
# 10000/10000 [==============================] - 398s 40ms/step - reward: 0.0167
# 13 episodes - episode_reward: 12.846 [6.000, 18.000] - loss: 0.016 - mae: 1.194 - mean_q: 1.444 - mean_eps: 0.679 - ale.lives: 2.149
#
# Interval 55 (540000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0179
# Guardando modelo en dqn_model_550000.h5
# 10000/10000 [==============================] - 397s 40ms/step - reward: 0.0179
# 13 episodes - episode_reward: 14.000 [6.000, 24.000] - loss: 0.014 - mae: 1.211 - mean_q: 1.464 - mean_eps: 0.673 - ale.lives: 2.106
#
# Interval 56 (550000 steps performed)
# 10000/10000 [==============================] - 401s 40ms/step - reward: 0.0181
# 13 episodes - episode_reward: 12.462 [8.000, 19.000] - loss: 0.015 - mae: 1.234 - mean_q: 1.491 - mean_eps: 0.667 - ale.lives: 2.178
#
# Interval 57 (560000 steps performed)
# 10000/10000 [==============================] - 400s 40ms/step - reward: 0.0171
# 16 episodes - episode_reward: 11.312 [4.000, 28.000] - loss: 0.015 - mae: 1.248 - mean_q: 1.506 - mean_eps: 0.661 - ale.lives: 2.198
#
# Interval 58 (570000 steps performed)
# 10000/10000 [==============================] - 408s 41ms/step - reward: 0.0165
# 15 episodes - episode_reward: 11.600 [5.000, 20.000] - loss: 0.015 - mae: 1.252 - mean_q: 1.511 - mean_eps: 0.655 - ale.lives: 2.106
#
# Interval 59 (580000 steps performed)
# 10000/10000 [==============================] - 408s 41ms/step - reward: 0.0175
# 15 episodes - episode_reward: 11.200 [6.000, 16.000] - loss: 0.016 - mae: 1.264 - mean_q: 1.526 - mean_eps: 0.649 - ale.lives: 2.164
#
# Interval 60 (590000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0188
# Guardando modelo en dqn_model_600000.h5
# 10000/10000 [==============================] - 413s 41ms/step - reward: 0.0188
# 14 episodes - episode_reward: 13.714 [7.000, 25.000] - loss: 0.016 - mae: 1.277 - mean_q: 1.542 - mean_eps: 0.643 - ale.lives: 2.178
#
# Interval 61 (600000 steps performed)
# 10000/10000 [==============================] - 414s 41ms/step - reward: 0.0193
# 15 episodes - episode_reward: 13.200 [6.000, 24.000] - loss: 0.015 - mae: 1.273 - mean_q: 1.535 - mean_eps: 0.637 - ale.lives: 2.160
#
# Interval 62 (610000 steps performed)
# 10000/10000 [==============================] - 417s 42ms/step - reward: 0.0172
# 15 episodes - episode_reward: 11.067 [5.000, 20.000] - loss: 0.015 - mae: 1.279 - mean_q: 1.543 - mean_eps: 0.631 - ale.lives: 2.175
#
# Interval 63 (620000 steps performed)
# 10000/10000 [==============================] - 419s 42ms/step - reward: 0.0167
# 16 episodes - episode_reward: 10.125 [5.000, 20.000] - loss: 0.016 - mae: 1.307 - mean_q: 1.575 - mean_eps: 0.625 - ale.lives: 2.217
#
# Interval 64 (630000 steps performed)
# 10000/10000 [==============================] - 418s 42ms/step - reward: 0.0179
# 13 episodes - episode_reward: 13.846 [6.000, 23.000] - loss: 0.015 - mae: 1.306 - mean_q: 1.575 - mean_eps: 0.619 - ale.lives: 2.070
#
# Interval 65 (640000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0185
# Guardando modelo en dqn_model_650000.h5
# 10000/10000 [==============================] - 419s 42ms/step - reward: 0.0185
# 16 episodes - episode_reward: 12.000 [5.000, 20.000] - loss: 0.014 - mae: 1.289 - mean_q: 1.552 - mean_eps: 0.613 - ale.lives: 2.137
#
# Interval 66 (650000 steps performed)
# 10000/10000 [==============================] - 417s 42ms/step - reward: 0.0166
# 16 episodes - episode_reward: 10.125 [5.000, 19.000] - loss: 0.014 - mae: 1.310 - mean_q: 1.579 - mean_eps: 0.607 - ale.lives: 2.179
#
# Interval 67 (660000 steps performed)
# 10000/10000 [==============================] - 429s 43ms/step - reward: 0.0189
# 13 episodes - episode_reward: 14.538 [6.000, 24.000] - loss: 0.014 - mae: 1.308 - mean_q: 1.576 - mean_eps: 0.601 - ale.lives: 2.000
#
# Interval 68 (670000 steps performed)
# 10000/10000 [==============================] - 427s 43ms/step - reward: 0.0190
# 13 episodes - episode_reward: 14.846 [8.000, 21.000] - loss: 0.014 - mae: 1.322 - mean_q: 1.592 - mean_eps: 0.595 - ale.lives: 2.101
#
# Interval 69 (680000 steps performed)
# 10000/10000 [==============================] - 433s 43ms/step - reward: 0.0187
# 14 episodes - episode_reward: 13.571 [6.000, 26.000] - loss: 0.014 - mae: 1.344 - mean_q: 1.618 - mean_eps: 0.589 - ale.lives: 2.119
#
# Interval 70 (690000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0175
# Guardando modelo en dqn_model_700000.h5
# 10000/10000 [==============================] - 437s 44ms/step - reward: 0.0175
# 13 episodes - episode_reward: 13.385 [9.000, 20.000] - loss: 0.014 - mae: 1.344 - mean_q: 1.618 - mean_eps: 0.583 - ale.lives: 2.092
#
# Interval 71 (700000 steps performed)
# 10000/10000 [==============================] - 437s 44ms/step - reward: 0.0160
# 11 episodes - episode_reward: 14.273 [7.000, 22.000] - loss: 0.014 - mae: 1.349 - mean_q: 1.623 - mean_eps: 0.577 - ale.lives: 2.180
#
# Interval 72 (710000 steps performed)
# 10000/10000 [==============================] - 443s 44ms/step - reward: 0.0172
# 16 episodes - episode_reward: 10.750 [6.000, 21.000] - loss: 0.014 - mae: 1.353 - mean_q: 1.628 - mean_eps: 0.571 - ale.lives: 2.121
#
# Interval 73 (720000 steps performed)
# 10000/10000 [==============================] - 433s 43ms/step - reward: 0.0168
# 13 episodes - episode_reward: 13.077 [6.000, 24.000] - loss: 0.014 - mae: 1.371 - mean_q: 1.649 - mean_eps: 0.565 - ale.lives: 2.213
#
# Interval 74 (730000 steps performed)
# 10000/10000 [==============================] - 434s 43ms/step - reward: 0.0192
# 14 episodes - episode_reward: 13.929 [5.000, 27.000] - loss: 0.014 - mae: 1.364 - mean_q: 1.641 - mean_eps: 0.559 - ale.lives: 2.147
#
# Interval 75 (740000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0189
# Guardando modelo en dqn_model_750000.h5
# 10000/10000 [==============================] - 435s 44ms/step - reward: 0.0189
# 12 episodes - episode_reward: 15.167 [4.000, 26.000] - loss: 0.014 - mae: 1.365 - mean_q: 1.642 - mean_eps: 0.553 - ale.lives: 2.060
#
# Interval 76 (750000 steps performed)
# 10000/10000 [==============================] - 444s 44ms/step - reward: 0.0202
# 13 episodes - episode_reward: 14.462 [6.000, 33.000] - loss: 0.014 - mae: 1.394 - mean_q: 1.678 - mean_eps: 0.547 - ale.lives: 2.320
#
# Interval 77 (760000 steps performed)
# 10000/10000 [==============================] - 441s 44ms/step - reward: 0.0176
# 14 episodes - episode_reward: 13.286 [7.000, 29.000] - loss: 0.015 - mae: 1.401 - mean_q: 1.687 - mean_eps: 0.541 - ale.lives: 2.044
#
# Interval 78 (770000 steps performed)
# 10000/10000 [==============================] - 452s 45ms/step - reward: 0.0199
# 14 episodes - episode_reward: 14.786 [7.000, 34.000] - loss: 0.015 - mae: 1.418 - mean_q: 1.706 - mean_eps: 0.535 - ale.lives: 2.068
#
# Interval 79 (780000 steps performed)
# 10000/10000 [==============================] - 447s 45ms/step - reward: 0.0180
# 13 episodes - episode_reward: 12.846 [5.000, 32.000] - loss: 0.015 - mae: 1.421 - mean_q: 1.710 - mean_eps: 0.529 - ale.lives: 2.080
#
# Interval 80 (790000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0173
# Guardando modelo en dqn_model_800000.h5
# 10000/10000 [==============================] - 447s 45ms/step - reward: 0.0173
# 16 episodes - episode_reward: 11.750 [6.000, 23.000] - loss: 0.016 - mae: 1.432 - mean_q: 1.723 - mean_eps: 0.523 - ale.lives: 2.082
#
# Interval 81 (800000 steps performed)
# 10000/10000 [==============================] - 439s 44ms/step - reward: 0.0179
# 12 episodes - episode_reward: 15.000 [7.000, 28.000] - loss: 0.015 - mae: 1.435 - mean_q: 1.727 - mean_eps: 0.517 - ale.lives: 2.039
#
# Interval 82 (810000 steps performed)
# 10000/10000 [==============================] - 439s 44ms/step - reward: 0.0179
# 13 episodes - episode_reward: 13.308 [6.000, 19.000] - loss: 0.016 - mae: 1.435 - mean_q: 1.726 - mean_eps: 0.511 - ale.lives: 2.147
#
# Interval 83 (820000 steps performed)
# 10000/10000 [==============================] - 445s 44ms/step - reward: 0.0183
# 14 episodes - episode_reward: 12.000 [8.000, 19.000] - loss: 0.015 - mae: 1.436 - mean_q: 1.725 - mean_eps: 0.505 - ale.lives: 2.133
#
# Interval 84 (830000 steps performed)
# 10000/10000 [==============================] - 449s 45ms/step - reward: 0.0170
# 15 episodes - episode_reward: 12.133 [6.000, 22.000] - loss: 0.015 - mae: 1.447 - mean_q: 1.738 - mean_eps: 0.499 - ale.lives: 2.126
#
# Interval 85 (840000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0145
# Guardando modelo en dqn_model_850000.h5
# 10000/10000 [==============================] - 450s 45ms/step - reward: 0.0145
# 14 episodes - episode_reward: 9.929 [7.000, 17.000] - loss: 0.015 - mae: 1.450 - mean_q: 1.743 - mean_eps: 0.493 - ale.lives: 2.183
#
# Interval 86 (850000 steps performed)
# 10000/10000 [==============================] - 455s 45ms/step - reward: 0.0160
# 12 episodes - episode_reward: 13.250 [5.000, 25.000] - loss: 0.016 - mae: 1.454 - mean_q: 1.748 - mean_eps: 0.487 - ale.lives: 1.995
#
# Interval 87 (860000 steps performed)
# 10000/10000 [==============================] - 457s 46ms/step - reward: 0.0173
# 15 episodes - episode_reward: 12.400 [5.000, 26.000] - loss: 0.015 - mae: 1.475 - mean_q: 1.774 - mean_eps: 0.481 - ale.lives: 1.990
#
# Interval 88 (870000 steps performed)
# 10000/10000 [==============================] - 459s 46ms/step - reward: 0.0183
# 13 episodes - episode_reward: 13.462 [8.000, 23.000] - loss: 0.016 - mae: 1.493 - mean_q: 1.796 - mean_eps: 0.475 - ale.lives: 2.211
#
# Interval 89 (880000 steps performed)
# 10000/10000 [==============================] - 466s 47ms/step - reward: 0.0178
# 11 episodes - episode_reward: 17.091 [8.000, 36.000] - loss: 0.015 - mae: 1.514 - mean_q: 1.820 - mean_eps: 0.469 - ale.lives: 2.022
#
# Interval 90 (890000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0168
# Guardando modelo en dqn_model_900000.h5
# 10000/10000 [==============================] - 456s 46ms/step - reward: 0.0168
# 14 episodes - episode_reward: 12.071 [3.000, 20.000] - loss: 0.015 - mae: 1.507 - mean_q: 1.811 - mean_eps: 0.463 - ale.lives: 2.070
#
# Interval 91 (900000 steps performed)
# 10000/10000 [==============================] - 460s 46ms/step - reward: 0.0168
# 13 episodes - episode_reward: 12.538 [4.000, 31.000] - loss: 0.016 - mae: 1.508 - mean_q: 1.813 - mean_eps: 0.457 - ale.lives: 2.114
#
# Interval 92 (910000 steps performed)
# 10000/10000 [==============================] - 465s 46ms/step - reward: 0.0193
# 12 episodes - episode_reward: 15.833 [7.000, 33.000] - loss: 0.015 - mae: 1.522 - mean_q: 1.830 - mean_eps: 0.451 - ale.lives: 2.188
#
# Interval 93 (920000 steps performed)
# 10000/10000 [==============================] - 465s 46ms/step - reward: 0.0192
# 13 episodes - episode_reward: 14.769 [3.000, 35.000] - loss: 0.016 - mae: 1.528 - mean_q: 1.837 - mean_eps: 0.445 - ale.lives: 2.020
#
# Interval 94 (930000 steps performed)
# 10000/10000 [==============================] - 473s 47ms/step - reward: 0.0186
# 12 episodes - episode_reward: 14.167 [7.000, 21.000] - loss: 0.016 - mae: 1.523 - mean_q: 1.831 - mean_eps: 0.439 - ale.lives: 2.072
#
# Interval 95 (940000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0193
# Guardando modelo en dqn_model_950000.h5
# 10000/10000 [==============================] - 474s 47ms/step - reward: 0.0193
# 14 episodes - episode_reward: 15.214 [8.000, 31.000] - loss: 0.015 - mae: 1.549 - mean_q: 1.862 - mean_eps: 0.433 - ale.lives: 2.121
#
# Interval 96 (950000 steps performed)
# 10000/10000 [==============================] - 476s 48ms/step - reward: 0.0183
# 13 episodes - episode_reward: 14.385 [8.000, 25.000] - loss: 0.016 - mae: 1.561 - mean_q: 1.876 - mean_eps: 0.427 - ale.lives: 2.037
#
# Interval 97 (960000 steps performed)
# 10000/10000 [==============================] - 483s 48ms/step - reward: 0.0187
# 10 episodes - episode_reward: 16.600 [8.000, 30.000] - loss: 0.017 - mae: 1.575 - mean_q: 1.894 - mean_eps: 0.421 - ale.lives: 2.002
#
# Interval 98 (970000 steps performed)
# 10000/10000 [==============================] - 483s 48ms/step - reward: 0.0176
# 13 episodes - episode_reward: 13.308 [6.000, 23.000] - loss: 0.015 - mae: 1.583 - mean_q: 1.902 - mean_eps: 0.415 - ale.lives: 2.012
#
# Interval 99 (980000 steps performed)
# 10000/10000 [==============================] - 482s 48ms/step - reward: 0.0175
# 13 episodes - episode_reward: 15.000 [5.000, 32.000] - loss: 0.016 - mae: 1.593 - mean_q: 1.914 - mean_eps: 0.409 - ale.lives: 2.118
#
# Interval 100 (990000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0176
# Guardando modelo en dqn_model_1000000.h5
# 10000/10000 [==============================] - 493s 49ms/step - reward: 0.0176
# 11 episodes - episode_reward: 15.364 [7.000, 28.000] - loss: 0.015 - mae: 1.580 - mean_q: 1.898 - mean_eps: 0.403 - ale.lives: 2.213
#
# Interval 101 (1000000 steps performed)
# 10000/10000 [==============================] - 492s 49ms/step - reward: 0.0208
# 14 episodes - episode_reward: 15.429 [6.000, 30.000] - loss: 0.015 - mae: 1.578 - mean_q: 1.895 - mean_eps: 0.397 - ale.lives: 2.016
#
# Interval 102 (1010000 steps performed)
# 10000/10000 [==============================] - 499s 50ms/step - reward: 0.0188
# 13 episodes - episode_reward: 13.615 [6.000, 24.000] - loss: 0.015 - mae: 1.553 - mean_q: 1.866 - mean_eps: 0.391 - ale.lives: 2.073
#
# Interval 103 (1020000 steps performed)
# 10000/10000 [==============================] - 500s 50ms/step - reward: 0.0184
# 13 episodes - episode_reward: 15.077 [3.000, 27.000] - loss: 0.015 - mae: 1.555 - mean_q: 1.869 - mean_eps: 0.385 - ale.lives: 2.148
#
# Interval 104 (1030000 steps performed)
# 10000/10000 [==============================] - 502s 50ms/step - reward: 0.0175
# 13 episodes - episode_reward: 12.692 [5.000, 28.000] - loss: 0.015 - mae: 1.548 - mean_q: 1.860 - mean_eps: 0.379 - ale.lives: 2.048
#
# Interval 105 (1040000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0209
# Guardando modelo en dqn_model_1050000.h5
# 10000/10000 [==============================] - 503s 50ms/step - reward: 0.0209
# 9 episodes - episode_reward: 23.778 [18.000, 33.000] - loss: 0.014 - mae: 1.570 - mean_q: 1.887 - mean_eps: 0.373 - ale.lives: 2.245
#
# Interval 106 (1050000 steps performed)
# 10000/10000 [==============================] - 507s 51ms/step - reward: 0.0184
# 12 episodes - episode_reward: 14.667 [9.000, 29.000] - loss: 0.014 - mae: 1.564 - mean_q: 1.879 - mean_eps: 0.367 - ale.lives: 2.207
#
# Interval 107 (1060000 steps performed)
# 10000/10000 [==============================] - 506s 51ms/step - reward: 0.0212
# 12 episodes - episode_reward: 18.917 [9.000, 28.000] - loss: 0.016 - mae: 1.591 - mean_q: 1.912 - mean_eps: 0.361 - ale.lives: 2.022
#
# Interval 108 (1070000 steps performed)
# 10000/10000 [==============================] - 497s 50ms/step - reward: 0.0216
# 13 episodes - episode_reward: 15.462 [6.000, 28.000] - loss: 0.014 - mae: 1.596 - mean_q: 1.918 - mean_eps: 0.355 - ale.lives: 2.180
#
# Interval 109 (1080000 steps performed)
# 10000/10000 [==============================] - 499s 50ms/step - reward: 0.0210
# 13 episodes - episode_reward: 15.615 [8.000, 22.000] - loss: 0.015 - mae: 1.593 - mean_q: 1.914 - mean_eps: 0.349 - ale.lives: 2.076
#
# Interval 110 (1090000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0190
# Guardando modelo en dqn_model_1100000.h5
# 10000/10000 [==============================] - 499s 50ms/step - reward: 0.0190
# 13 episodes - episode_reward: 15.308 [8.000, 30.000] - loss: 0.014 - mae: 1.594 - mean_q: 1.914 - mean_eps: 0.343 - ale.lives: 2.093
#
# Interval 111 (1100000 steps performed)
# 10000/10000 [==============================] - 499s 50ms/step - reward: 0.0209
# 14 episodes - episode_reward: 15.786 [6.000, 28.000] - loss: 0.015 - mae: 1.581 - mean_q: 1.900 - mean_eps: 0.337 - ale.lives: 2.085
#
# Interval 112 (1110000 steps performed)
# 10000/10000 [==============================] - 503s 50ms/step - reward: 0.0209
# 13 episodes - episode_reward: 15.000 [2.000, 25.000] - loss: 0.016 - mae: 1.579 - mean_q: 1.899 - mean_eps: 0.331 - ale.lives: 2.038
#
# Interval 113 (1120000 steps performed)
# 10000/10000 [==============================] - 508s 51ms/step - reward: 0.0194
# 12 episodes - episode_reward: 17.083 [11.000, 24.000] - loss: 0.016 - mae: 1.610 - mean_q: 1.937 - mean_eps: 0.325 - ale.lives: 2.005
#
# Interval 114 (1130000 steps performed)
# 10000/10000 [==============================] - 505s 50ms/step - reward: 0.0218
# 11 episodes - episode_reward: 19.091 [14.000, 26.000] - loss: 0.016 - mae: 1.607 - mean_q: 1.933 - mean_eps: 0.319 - ale.lives: 2.017
#
# Interval 115 (1140000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0204
# Guardando modelo en dqn_model_1150000.h5
# 10000/10000 [==============================] - 504s 50ms/step - reward: 0.0204
# 11 episodes - episode_reward: 18.364 [13.000, 26.000] - loss: 0.015 - mae: 1.599 - mean_q: 1.922 - mean_eps: 0.313 - ale.lives: 2.174
#
# Interval 116 (1150000 steps performed)
# 10000/10000 [==============================] - 508s 51ms/step - reward: 0.0204
# 12 episodes - episode_reward: 17.083 [9.000, 23.000] - loss: 0.015 - mae: 1.616 - mean_q: 1.943 - mean_eps: 0.307 - ale.lives: 2.224
#
# Interval 117 (1160000 steps performed)
# 10000/10000 [==============================] - 506s 51ms/step - reward: 0.0232
# 13 episodes - episode_reward: 18.692 [13.000, 30.000] - loss: 0.015 - mae: 1.634 - mean_q: 1.965 - mean_eps: 0.301 - ale.lives: 1.948
#
# Interval 118 (1170000 steps performed)
# 10000/10000 [==============================] - 508s 51ms/step - reward: 0.0217
# 11 episodes - episode_reward: 19.091 [8.000, 28.000] - loss: 0.015 - mae: 1.610 - mean_q: 1.935 - mean_eps: 0.295 - ale.lives: 2.037
#
# Interval 119 (1180000 steps performed)
# 10000/10000 [==============================] - 506s 51ms/step - reward: 0.0203
# 14 episodes - episode_reward: 14.643 [9.000, 23.000] - loss: 0.015 - mae: 1.613 - mean_q: 1.939 - mean_eps: 0.289 - ale.lives: 2.063
#
# Interval 120 (1190000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0213
# Guardando modelo en dqn_model_1200000.h5
# 10000/10000 [==============================] - 505s 50ms/step - reward: 0.0213
# 11 episodes - episode_reward: 18.455 [6.000, 24.000] - loss: 0.016 - mae: 1.627 - mean_q: 1.954 - mean_eps: 0.283 - ale.lives: 2.207
#
# Interval 121 (1200000 steps performed)
# 10000/10000 [==============================] - 512s 51ms/step - reward: 0.0215
# 13 episodes - episode_reward: 17.385 [6.000, 24.000] - loss: 0.015 - mae: 1.614 - mean_q: 1.940 - mean_eps: 0.277 - ale.lives: 2.068
#
# Interval 122 (1210000 steps performed)
# 10000/10000 [==============================] - 502s 50ms/step - reward: 0.0194
# 13 episodes - episode_reward: 15.385 [4.000, 22.000] - loss: 0.015 - mae: 1.606 - mean_q: 1.930 - mean_eps: 0.271 - ale.lives: 1.863
#
# Interval 123 (1220000 steps performed)
# 10000/10000 [==============================] - 502s 50ms/step - reward: 0.0212
# 13 episodes - episode_reward: 15.846 [10.000, 21.000] - loss: 0.015 - mae: 1.622 - mean_q: 1.950 - mean_eps: 0.265 - ale.lives: 2.130
#
# Interval 124 (1230000 steps performed)
# 10000/10000 [==============================] - 504s 50ms/step - reward: 0.0207
# 12 episodes - episode_reward: 16.417 [5.000, 23.000] - loss: 0.014 - mae: 1.626 - mean_q: 1.954 - mean_eps: 0.259 - ale.lives: 2.124
#
# Interval 125 (1240000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0184
# Guardando modelo en dqn_model_1250000.h5
# 10000/10000 [==============================] - 506s 51ms/step - reward: 0.0184
# 13 episodes - episode_reward: 15.000 [6.000, 26.000] - loss: 0.014 - mae: 1.633 - mean_q: 1.961 - mean_eps: 0.253 - ale.lives: 1.953
#
# Interval 126 (1250000 steps performed)
# 10000/10000 [==============================] - 504s 50ms/step - reward: 0.0217
# 14 episodes - episode_reward: 15.500 [8.000, 25.000] - loss: 0.015 - mae: 1.649 - mean_q: 1.981 - mean_eps: 0.247 - ale.lives: 2.039
#
# Interval 127 (1260000 steps performed)
# 10000/10000 [==============================] - 506s 51ms/step - reward: 0.0185
# 12 episodes - episode_reward: 14.500 [4.000, 20.000] - loss: 0.015 - mae: 1.656 - mean_q: 1.990 - mean_eps: 0.241 - ale.lives: 2.194
#
# Interval 128 (1270000 steps performed)
# 10000/10000 [==============================] - 501s 50ms/step - reward: 0.0223
# 13 episodes - episode_reward: 17.000 [11.000, 24.000] - loss: 0.015 - mae: 1.681 - mean_q: 2.021 - mean_eps: 0.235 - ale.lives: 2.065
#
# Interval 129 (1280000 steps performed)
# 10000/10000 [==============================] - 505s 50ms/step - reward: 0.0182
# 15 episodes - episode_reward: 12.933 [4.000, 20.000] - loss: 0.014 - mae: 1.694 - mean_q: 2.036 - mean_eps: 0.229 - ale.lives: 2.046
#
# Interval 130 (1290000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0200
# Guardando modelo en dqn_model_1300000.h5
# 10000/10000 [==============================] - 501s 50ms/step - reward: 0.0200
# 13 episodes - episode_reward: 15.846 [6.000, 28.000] - loss: 0.014 - mae: 1.700 - mean_q: 2.043 - mean_eps: 0.223 - ale.lives: 2.081
#
# Interval 131 (1300000 steps performed)
# 10000/10000 [==============================] - 494s 49ms/step - reward: 0.0206
# 12 episodes - episode_reward: 16.667 [7.000, 24.000] - loss: 0.014 - mae: 1.707 - mean_q: 2.051 - mean_eps: 0.217 - ale.lives: 2.331
#
# Interval 132 (1310000 steps performed)
# 10000/10000 [==============================] - 490s 49ms/step - reward: 0.0213
# 14 episodes - episode_reward: 15.643 [6.000, 32.000] - loss: 0.015 - mae: 1.714 - mean_q: 2.061 - mean_eps: 0.211 - ale.lives: 2.066
#
# Interval 133 (1320000 steps performed)
# 10000/10000 [==============================] - 498s 50ms/step - reward: 0.0202
# 13 episodes - episode_reward: 14.231 [2.000, 23.000] - loss: 0.014 - mae: 1.712 - mean_q: 2.059 - mean_eps: 0.205 - ale.lives: 2.105
#
# Interval 134 (1330000 steps performed)
# 10000/10000 [==============================] - 492s 49ms/step - reward: 0.0219
# 12 episodes - episode_reward: 19.417 [8.000, 32.000] - loss: 0.016 - mae: 1.716 - mean_q: 2.062 - mean_eps: 0.199 - ale.lives: 2.192
#
# Interval 135 (1340000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0207
# Guardando modelo en dqn_model_1350000.h5
# 10000/10000 [==============================] - 502s 50ms/step - reward: 0.0207
# 13 episodes - episode_reward: 14.615 [5.000, 22.000] - loss: 0.014 - mae: 1.720 - mean_q: 2.068 - mean_eps: 0.193 - ale.lives: 2.024
#
# Interval 136 (1350000 steps performed)
# 10000/10000 [==============================] - 483s 48ms/step - reward: 0.0220
# 12 episodes - episode_reward: 19.667 [6.000, 26.000] - loss: 0.015 - mae: 1.739 - mean_q: 2.091 - mean_eps: 0.187 - ale.lives: 2.169
#
# Interval 137 (1360000 steps performed)
# 10000/10000 [==============================] - 490s 49ms/step - reward: 0.0213
# 13 episodes - episode_reward: 16.077 [5.000, 25.000] - loss: 0.015 - mae: 1.756 - mean_q: 2.111 - mean_eps: 0.181 - ale.lives: 2.061
#
# Interval 138 (1370000 steps performed)
# 10000/10000 [==============================] - 486s 49ms/step - reward: 0.0211
# 13 episodes - episode_reward: 16.000 [10.000, 26.000] - loss: 0.015 - mae: 1.772 - mean_q: 2.130 - mean_eps: 0.175 - ale.lives: 2.084
#
# Interval 139 (1380000 steps performed)
# 10000/10000 [==============================] - 494s 49ms/step - reward: 0.0194
# 10 episodes - episode_reward: 18.500 [11.000, 24.000] - loss: 0.015 - mae: 1.760 - mean_q: 2.114 - mean_eps: 0.169 - ale.lives: 2.024
#
# Interval 140 (1390000 steps performed)
#  9997/10000 [============================>.] - ETA: 0s - reward: 0.0166
# Guardando modelo en dqn_model_1400000.h5
# 10000/10000 [==============================] - 489s 49ms/step - reward: 0.0166
# 12 episodes - episode_reward: 15.167 [2.000, 21.000] - loss: 0.015 - mae: 1.735 - mean_q: 2.085 - mean_eps: 0.163 - ale.lives: 2.025
#
# Interval 141 (1400000 steps performed)
# 10000/10000 [==============================] - 490s 49ms/step - reward: 0.0218
# 13 episodes - episode_reward: 16.231 [8.000, 33.000] - loss: 0.015 - mae: 1.763 - mean_q: 2.119 - mean_eps: 0.157 - ale.lives: 2.155
#
# Interval 142 (1410000 steps performed)
# 10000/10000 [==============================] - 493s 49ms/step - reward: 0.0208
# 13 episodes - episode_reward: 16.846 [9.000, 26.000] - loss: 0.015 - mae: 1.760 - mean_q: 2.115 - mean_eps: 0.151 - ale.lives: 1.988
#
# Interval 143 (1420000 steps performed)
# 10000/10000 [==============================] - 491s 49ms/step - reward: 0.0202
# 12 episodes - episode_reward: 16.833 [9.000, 28.000] - loss: 0.015 - mae: 1.775 - mean_q: 2.133 - mean_eps: 0.145 - ale.lives: 2.131
#
# Interval 144 (1430000 steps performed)
#  2741/10000 [=======>......................] - ETA: 5:56 - reward: 0.0182

# %%
# Testing part to calculate the mean reward
weights_filename = 'dqn_{}_weights.h5f'.format(env_name)
dqn.load_weights(weights_filename)
dqn.test(env, nb_episodes=10, visualize=False)

# %% [markdown]
# 3. Justificación de los parámetros seleccionados y de los resultados obtenidos

# %% [markdown]
# ---
